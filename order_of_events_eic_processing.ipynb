# %%
import pandas as pd
import numpy as np
from scipy.integrate import simpson
from findpeaks import findpeaks
import os
import matplotlib.pyplot as plt
from cmcrameri import cm

# %%
def split_tsv(path_to_file):
    print(path_to_file)
    def read_file_for_headers(path_to_file):
        tsv_file = open(path_to_file, "r", encoding = "ISO-8859-1").readlines()
        header_line_idxs = []
        for line_idx in range(len(tsv_file)):
            if "!NAME!" in tsv_file[line_idx]:
                header_line_idxs.append(line_idx)
        return header_line_idxs

    header_line_idxs = read_file_for_headers(path_to_file) 

    tsv_df = pd.read_csv(path_to_file, delimiter='\t', encoding = "ISO-8859-1", on_bad_lines='skip', names=['time', 'counts'])
    
    split_df = []
    for idx in range(len(header_line_idxs)):
        header_idx = header_line_idxs[idx]
        table_start = header_idx + 1
        if idx+1 != len(header_line_idxs):
            table_end = header_line_idxs[idx+1] - 1
        else:
            table_end = tsv_df.shape[0]
            
        new_df = tsv_df.iloc[table_start: table_end]
        new_df["time"] = pd.to_numeric(new_df["time"])
        new_df = new_df.reset_index()
        name = tsv_df.iloc[header_idx].values[0]
        name = name.replace("!NAME!","")
        name= name.split('!CHROMNAME!', 1)[0]
        split_df.append({'name': name,'df': new_df})
    return split_df[:-2]

def return_peaks(df):
    fp = findpeaks(method='peakdetect',lookahead=5, interpolate=5)
    peak_results = fp.fit(df['counts'])
    peaks_df = peak_results['df']

    return peaks_df

def return_noise_height(df, peaks_df, noise_start=0, noise_end=30):
    times = df['time']
    time_closest_to_noise_start = times[times >= noise_start].min()
    time_closest_to_noise_end = times[times <= noise_end].max()
    time_closest_to_noise_start_idx = times[times == time_closest_to_noise_start].index[0]
    time_closest_to_noise_end_idx = times[times == time_closest_to_noise_end].index[0]

    peaks_df_idxs = peaks_df['x']
    peaks_df_idx_closest_to_noise_start_idx = peaks_df_idxs[peaks_df_idxs >= time_closest_to_noise_start_idx].min()
    peaks_df_idx_closest_to_noise_end_idx = peaks_df_idxs[peaks_df_idxs <= time_closest_to_noise_end_idx].max()

    noise_valleys = peaks_df[(peaks_df['x'] >= peaks_df_idx_closest_to_noise_start_idx) & (peaks_df['x'] <= peaks_df_idx_closest_to_noise_end_idx) & (peaks_df['valley'] == True)]['y']
    noise_peaks = peaks_df[(peaks_df['x'] >= peaks_df_idx_closest_to_noise_start_idx) & (peaks_df['x'] <= peaks_df_idx_closest_to_noise_end_idx) & (peaks_df['peak'] == True)]['y']

    noise_height = noise_peaks.mean() - noise_valleys.mean()

    return noise_height

def return_noise_height2(df, peaks_df, noise_exclude1, noise_exclude2):
    times = df['time']
    print(peaks_df)
    time_closest_to_noise_exclude1 = times[times >= noise_exclude1].min()
    time_closest_to_noise_exclude2 = times[times <= noise_exclude2].max()
    time_closest_to_noise_exclude1_idx = times[times == time_closest_to_noise_exclude1].index[0]
    time_closest_to_noise_exclude2_idx = times[times == time_closest_to_noise_exclude2].index[0]

    peaks_df_idxs = peaks_df['x']
    peaks_df_idx_closest_to_noise_exclude1_idx = peaks_df_idxs[peaks_df_idxs >= time_closest_to_noise_exclude1_idx].min()
    peaks_df_idx_closest_to_noise_exclude2_idx = peaks_df_idxs[peaks_df_idxs <= time_closest_to_noise_exclude2_idx].max()

    noise_valleys = peaks_df[((peaks_df['x'] <= peaks_df_idx_closest_to_noise_exclude1_idx) | (peaks_df['x'] >= peaks_df_idx_closest_to_noise_exclude2_idx)) & (peaks_df['valley'] == True)]['y']
    noise_peaks = peaks_df[((peaks_df['x'] <= peaks_df_idx_closest_to_noise_exclude1_idx) | (peaks_df['x'] >= peaks_df_idx_closest_to_noise_exclude2_idx)) & (peaks_df['peak'] == True)]['y']

    noise_height = noise_peaks.mean() - noise_valleys.mean()

    return noise_height

def mainpeak(df, peaks_df):
    try:
        maxpeak = peaks_df[peaks_df['y'] == peaks_df['y'].max()]
        maxpeak_idx = maxpeak.index[0]
        valley_idxs = peaks_df[peaks_df['valley'] == True].index.to_list()
        start_idx = np.asarray(valley_idxs)[np.asarray(valley_idxs) < maxpeak_idx].max()
        end_idx = np.asarray(valley_idxs)[np.asarray(valley_idxs) > maxpeak_idx].min()
        
        if len(maxpeak) == 1: 
            main_peak_time = df['time'].iloc[maxpeak['x'].item()]
            main_peak_count = maxpeak['y'].item()
            start_main_peak = df['time'].iloc[peaks_df.iloc[start_idx]['x'].item()]
            end_main_peak = df['time'].iloc[peaks_df.iloc[end_idx]['x'].item()]
            return {'main_peak_count': main_peak_count, 'main_peak_meantime': main_peak_time, 'main_peak_start':start_main_peak, 'main_peak_end':end_main_peak}
        if len(maxpeak) > 1: 
            maxpeak = maxpeak.iloc[0]
            print('Warning more than two max peaks - taking the first')
            main_peak_time = df['time'].iloc[maxpeak['x'].item()]
            main_peak_count = maxpeak['y'].item()
            start_main_peak = df['time'].iloc[peaks_df.iloc[start_idx]['x'].item()]
            end_main_peak = df['time'].iloc[peaks_df.iloc[end_idx]['x'].item()]
            return {'main_peak_count': main_peak_count, 'main_peak_meantime': main_peak_time, 'main_peak_start':start_main_peak, 'main_peak_end':end_main_peak}
    except:
        return {'main_peak_count': np.nan, 'main_peak_meantime': np.nan, 'main_peak_start':np.nan, 'main_peak_end':np.nan}

def return_signal_to_noise(noise_height, peak_height):
    try:
        return (peak_height * 2) / noise_height
    except:
        return 'error'

def eval_signal_to_noise(main_peak_area, sn_ratio, threshold = 100):
    print(sn_ratio)
    if type(sn_ratio) == str:
        return 'error'
    if sn_ratio < threshold:
        return 0
    
    return main_peak_area

def eicarea(df):
    area = abs(simpson(df['counts']))
    return area

def mainpeak_area(df, start_limit, end_limit):
    limit_df = df[(df['time'] <= end_limit) & (df['time'] >=  start_limit)]
    limit_area = abs(simpson(limit_df['counts']))
    return limit_area

def draw_chromatogram(df, name, dir, filename):
    fig, ax = plt.subplots(figsize=(15,5))

    x_max = max(list(df['time']))
    y_max = df['counts'].max()

    ax.set_title(f'EIC for {name}')
    ax.plot(df['time'], df['counts'], linewidth=1.0, color='#6F1F70')
    ax.fill_between(df['time'], df['counts'], 0, color='#6F1F70',alpha=0.2)
    ax.set_xticks(np.linspace(0, x_max, 6))
    
    ax.set_xlim(0, x_max)
    ax.set_ylim(0, y_max+y_max*0.05)
    ax.ticklabel_format(axis='y', style='sci')
    ax.set_xlabel('time (mins)')
    ax.set_ylabel('counts (arb)')
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    
    output_dir = os.path.join(dir, '_raw_eics')
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    plt.savefig(os.path.join(output_dir, filename+".svg"), cmap=cm.romaO)
    plt.close()

def draw_chromatogram_annonated(df, eic_area, mainpeak_info, name, dir, filename):
    fig, (ax,ax2) = plt.subplots(1,2, figsize=(10,4))

    x_max = max(list(df['time']))
    y_max = df['counts'].max()

    fig.suptitle(f'EIC for {name}')
    ax.plot(df['time'], df['counts'], linewidth=1.0, color='#D28B15')

    t = (f"SN ratio too low!\nEIC area: {eic_area} arbs\n"
         f"Main peak\n    Height: {mainpeak_info['main_peak_count']} counts\n    Apex time: {mainpeak_info['main_peak_meantime']} secs\n    Area: {mainpeak_info['main_peak_area_eval']} arbs\n    SN ratio:{mainpeak_info['sn_ratio']}")
    if mainpeak_info['sn_ratio'] > 100:
        ax.plot(mainpeak_info['main_peak_meantime'], mainpeak_info['main_peak_count'], "x")
        ax.axvline(x=mainpeak_info['main_peak_start'], color = 'gray', linestyle = '--', linewidth=1)
        ax.axvline(x=mainpeak_info['main_peak_end'], color = 'gray', linestyle = '--', linewidth=1)
    
        df_sliced = df[(df['time'] >= mainpeak_info['main_peak_start'])&(df['time'] <= mainpeak_info['main_peak_end'])]
        ax.fill_between(df_sliced['time'], df_sliced['counts'], 0, color='#D28B15',alpha=0.2)
        t = (f"EIC area: {eic_area} arbs\n"
         f"Main peak\n    Height: {mainpeak_info['main_peak_count']} counts\n    Apex time: {mainpeak_info['main_peak_meantime']} secs\n    Start time (1st grey line): {mainpeak_info['main_peak_start']} secs \n    End time (2nd grey line): {mainpeak_info['main_peak_end']} secs\n    Area: {mainpeak_info['main_peak_area_eval']} arbs\n   SN ratio:{mainpeak_info['sn_ratio']}")
    
        
        
    ax.set_xticks(np.linspace(0, x_max, 6))
    
    ax.set_xlim(0, x_max)
    ax.set_ylim(0, y_max+y_max*0.05)
    ax.ticklabel_format(axis='y', style='sci')
    ax.set_xlabel('time (mins)')
    ax.set_ylabel('counts (arb)')
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)


    ax2.spines['right'].set_visible(False)
    ax2.spines['top'].set_visible(False)
    ax2.spines['bottom'].set_visible(False)
    ax2.spines['left'].set_visible(False)
    ax2.get_xaxis().set_visible(False)
    ax2.get_yaxis().set_visible(False)
    
    ax2.text(0.05, 0.95, t, horizontalalignment='left', verticalalignment='top', transform = ax2.transAxes)
    

    output_dir = os.path.join(dir, '_annotated_eics')
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    plt.savefig(os.path.join(output_dir, filename+".svg"), cmap=cm.romaO)
    plt.close()

# %%
def generate_eicdata_tsv(path_to_file):
    file_name = os.path.splitext(os.path.basename(path_to_file))[0]
    file_dir = os.path.dirname(path_to_file)
    tsv_list = split_tsv(path_to_file)

    name_areas = []
    for df_dict in tsv_list:
        df = df_dict['df']
        if 'TIC' in df_dict['name'] or 'BPC' in df_dict['name']:
            eic_area = eicarea(df)
            name_areas.append({'file_name': file_name,
                               'strain_name': " ".join(file_name.split("_", 2)[:2]),
                               'repeat': file_name.split("_")[2],
                               'eic_name': df_dict['name'],
                               'eic_area': eic_area, 
                               'main_peak_count': np.nan, 
                               'main_peak_meantime': np.nan, 
                               'main_peak_start': np.nan, 
                               'main_peak_end': np.nan,
                               'main_peak_area': np.nan,
                               'noise_height': np.nan,
                               'main_peak_snratio': np.nan
                            })
            draw_chromatogram(df, file_name+df_dict['name'].replace("∆", "del"), file_dir, file_name+df_dict['name'].replace("∆", "del"))
        else:
            peaks_df = return_peaks(df)
            mainpeak_info = mainpeak(df, peaks_df)
            if mainpeak_info['main_peak_count'] != mainpeak_info['main_peak_count']:
                mainpeak_info['main_peak_area'] = np.nan
                noise_height = np.nan
                mainpeak_info['sn_ratio'] = np.nan
                mainpeak_info['main_peak_area_eval'] = np.nan
                eic_area = eicarea(df)
            else:
                print(mainpeak_info)
                mainpeak_info['main_peak_area'] = mainpeak_area(df, mainpeak_info['main_peak_start'], mainpeak_info['main_peak_end'])
                eic_area = eicarea(df)
                noise_height = return_noise_height2(df, peaks_df, mainpeak_info['main_peak_start'], mainpeak_info['main_peak_end'])
                mainpeak_info['sn_ratio'] = return_signal_to_noise(noise_height, mainpeak_info['main_peak_count'])
                mainpeak_info['main_peak_area_eval'] = eval_signal_to_noise(mainpeak_info['main_peak_area'], mainpeak_info['sn_ratio'])
                
            name_areas.append({'file_name': file_name,
                               'strain_name': " ".join(file_name.split("_", 2)[:2]),
                               'repeat': file_name.split("_")[2],
                               'eic_name': df_dict['name'],
                               'eic_area': eic_area, 
                               'main_peak_count': mainpeak_info['main_peak_count'], 
                               'main_peak_meantime': mainpeak_info['main_peak_meantime'], 
                               'main_peak_start': mainpeak_info['main_peak_start'], 
                               'main_peak_end': mainpeak_info['main_peak_end'],
                               'main_peak_area': mainpeak_info['main_peak_area'],
                               'noise_height': noise_height,
                               'main_peak_snratio': mainpeak_info['sn_ratio'],
                               'main_peak_area_eval': mainpeak_info['main_peak_area_eval']
                            })
            draw_chromatogram(df, file_name+"_"+df_dict['name'].replace("/", "_"), file_dir, file_name+"_"+df_dict['name'].replace("/", "_"))
            try:
                draw_chromatogram_annonated(df, eic_area, mainpeak_info, file_name+"_"+df_dict['name'].replace("/", "_"), file_dir, "ANNOTATED_"+file_name+"_"+df_dict['name'].replace("/", "_"))
            except:
                pass
            

    eicarea_tsv = pd.DataFrame(name_areas)
    
    return eicarea_tsv

# %%
def eicarea_tsv_fromdir(path_to_dir):
    df_list = []
    file_dir = os.path.dirname(path_to_dir)
    for item in os.listdir(file_dir):
        item_path = file_dir + "/" + item
        if os.path.isfile(item_path) and item_path.endswith('.tsv'):
            df_list.append(generate_eicdata_tsv(item_path))
            

    concat_df = pd.concat(df_list)
    concat_df.to_csv(os.path.join(path_to_dir, 'eic.csv'), index=False)

# %%
eicarea_tsv_fromdir("/Volumes/MICHAEL E-H 1/BIFFAMYCIN/Biffamycin Media Screen/17Sep_Reanalysis/1/")
eicarea_tsv_fromdir("/Volumes/MICHAEL E-H 1/BIFFAMYCIN/Biffamycin Media Screen/17Sep_Reanalysis/2/")
eicarea_tsv_fromdir("/Volumes/MICHAEL E-H 1/BIFFAMYCIN/Biffamycin Media Screen/17Sep_Reanalysis/3/")
eicarea_tsv_fromdir("/Volumes/MICHAEL E-H 1/BIFFAMYCIN/Biffamycin Media Screen/17Sep_Reanalysis/4/")
# Out:
# /Volumes/MICHAEL E-H 1/BIFFAMYCIN/Biffamycin Media Screen/17Sep_Reanalysis/1/EICs_Q5All_ISP2_1_1-1-10_1_1298.d.tsv
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 3027.0, 'main_peak_meantime': 262.87, 'main_peak_start': 260.317, 'main_peak_end': 271.915}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True  False
# 1    0.0    1    1.0   False  False
# 2    0.0    2    2.0    True  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    3.0    True  False
# ..   ...  ...    ...     ...    ...
# 463  0.0  463  166.0   False  False
# 464  0.0  464  167.0   False  False
# 465  0.0  465  167.0   False  False
# 466  0.0  466  168.0   False  False
# 467  0.0  467  168.0   False  False
#
# [468 rows x 5 columns]
# 167.6427829698858
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 25278.0, 'main_peak_meantime': 268.544, 'main_peak_start': 260.317, 'main_peak_end': 278.817}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0    True  False
# 2    0.0    2    2.0   False   True
# 3    0.0    3    2.0    True  False
# 4    0.0    4    3.0   False   True
# ..   ...  ...    ...     ...    ...
# 463  0.0  463  161.0    True  False
# 464  0.0  464  162.0   False  False
# 465  0.0  465  162.0   False  False
# 466  0.0  466  163.0   False  False
# 467  0.0  467  163.0   False  False
#
# [468 rows x 5 columns]
# 712.7346161173557
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 8737.0, 'main_peak_meantime': 212.308, 'main_peak_start': 207.627, 'main_peak_end': 219.508}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1    10.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 463   9.0  463  155.0   False  False
# 464   0.0  464  155.0    True  False
# 465  14.0  465  156.0   False   True
# 466  12.0  466  156.0   False  False
# 467   0.0  467  156.0   False  False
#
# [468 rows x 5 columns]
# 149.61683910096326
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 4654.0, 'main_peak_meantime': 257.535, 'main_peak_start': 255.193, 'main_peak_end': 262.87}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 463   0.0  463  175.0    True  False
# 464  21.0  464  176.0   False  False
# 465   0.0  465  176.0   False  False
# 466  25.0  466  177.0   False  False
# 467  31.0  467  177.0   False   True
#
# [468 rows x 5 columns]
# 153.17493237150586
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 131.0, 'main_peak_meantime': 246.724, 'main_peak_start': 245.939, 'main_peak_end': 248.602}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True  False
# 1    0.0    1    1.0   False  False
# 2    0.0    2    1.0   False  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    2.0    True  False
# ..   ...  ...    ...     ...    ...
# 463  0.0  463  158.0   False  False
# 464  0.0  464  158.0   False  False
# 465  0.0  465  159.0   False  False
# 466  0.0  466  159.0   False  False
# 467  0.0  467  159.0   False  False
#
# [468 rows x 5 columns]
# 5.879867986798679
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 201.0, 'main_peak_meantime': 218.626, 'main_peak_start': 217.863, 'main_peak_end': 221.053}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2    40.0    2    1.0   False   True
# 3     0.0    3    1.0   False  False
# 4    14.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 463   0.0  463  172.0   False  False
# 464   0.0  464  173.0   False  False
# 465   0.0  465  173.0   False  False
# 466  22.0  466  174.0   False   True
# 467   0.0  467  174.0   False  False
#
# [468 rows x 5 columns]
# 6.185820023373588
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1297.0, 'main_peak_meantime': 242.829, 'main_peak_start': 242.061, 'main_peak_end': 244.401}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False   True
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 463   0.0  463  161.0   False  False
# 464   0.0  464  162.0   False  False
# 465   0.0  465  162.0   False  False
# 466  24.0  466  163.0   False   True
# 467  21.0  467  163.0   False  False
#
# [468 rows x 5 columns]
# 62.101585247492714
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1430.0, 'main_peak_meantime': 167.93, 'main_peak_start': 165.597, 'main_peak_end': 169.476}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 463   0.0  463  165.0   False  False
# 464   0.0  464  165.0   False  False
# 465  27.0  465  165.0   False   True
# 466  20.0  466  165.0   False  False
# 467   0.0  467  165.0   False  False
#
# [468 rows x 5 columns]
# 34.46847960444994
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 220.0, 'main_peak_meantime': 234.491, 'main_peak_start': 232.024, 'main_peak_end': 236.7}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False  False
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 463   0.0  463  163.0    True  False
# 464  21.0  464  164.0   False   True
# 465  20.0  465  164.0   False  False
# 466   0.0  466  164.0   False  False
# 467  29.0  467  164.0   False   True
#
# [468 rows x 5 columns]
# 9.799554565701559
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 357.0, 'main_peak_meantime': 196.658, 'main_peak_start': 195.892, 'main_peak_end': 197.55}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3    18.0    3    2.0   False   True
# 4    14.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 463   0.0  463  182.0   False  False
# 464   0.0  464  182.0   False  False
# 465   0.0  465  183.0   False  False
# 466   0.0  466  183.0   False  False
# 467   0.0  467  183.0   False  False
#
# [468 rows x 5 columns]
# 16.960495739736636
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 169.0, 'main_peak_meantime': 214.606, 'main_peak_start': 213.082, 'main_peak_end': 215.376}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2    11.0    2    1.0   False   True
# 3     0.0    3    1.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 463  17.0  463  162.0   False  False
# 464  22.0  464  162.0   False   True
# 465   0.0  465  162.0   False  False
# 466   0.0  466  163.0   False  False
# 467   0.0  467  163.0   False  False
#
# [468 rows x 5 columns]
# 7.232095096582466
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 328.0, 'main_peak_meantime': 202.375, 'main_peak_start': 199.89, 'main_peak_end': 203.156}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    1.0   False  False
# 3     0.0    3    2.0    True  False
# 4     8.0    4    2.0   False   True
# ..    ...  ...    ...     ...    ...
# 463  45.0  463  178.0   False   True
# 464   0.0  464  178.0    True  False
# 465   0.0  465  179.0   False  False
# 466   0.0  466  179.0   False  False
# 467  19.0  467  179.0   False  False
#
# [468 rows x 5 columns]
# 7.40081479160138
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 201.0, 'main_peak_meantime': 241.177, 'main_peak_start': 234.491, 'main_peak_end': 242.061}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0   False  False
# 2    0.0    2    1.0    True  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    2.0   False  False
# ..   ...  ...    ...     ...    ...
# 463  0.0  463  167.0   False  False
# 464  0.0  464  168.0   False  False
# 465  0.0  465  168.0   False  False
# 466  0.0  466  169.0   False  False
# 467  0.0  467  169.0   False  False
#
# [468 rows x 5 columns]
# 9.14221652786675
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 545.0, 'main_peak_meantime': 242.061, 'main_peak_start': 240.329, 'main_peak_end': 243.624}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 463  45.0  463  176.0   False  False
# 464  47.0  464  176.0   False  False
# 465  29.0  465  176.0    True  False
# 466  29.0  466  177.0   False  False
# 467  39.0  467  177.0   False  False
#
# [468 rows x 5 columns]
# 12.36134168050083
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 348.0, 'main_peak_meantime': 393.861, 'main_peak_start': 388.417, 'main_peak_end': 395.464}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0   False  False
# 2     0.0    2    2.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    3.0    True  False
# ..    ...  ...    ...     ...    ...
# 463  24.0  463  160.0   False  False
# 464  50.0  464  161.0   False  False
# 465  44.0  465  161.0   False  False
# 466  38.0  466  161.0   False  False
# 467   0.0  467  161.0    True  False
#
# [468 rows x 5 columns]
# 11.229237247015167
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 438.0, 'main_peak_meantime': 206.842, 'main_peak_start': 204.873, 'main_peak_end': 207.627}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    1.0   False  False
# 3     0.0    3    2.0   False  False
# 4    14.0    4    2.0   False   True
# ..    ...  ...    ...     ...    ...
# 463   0.0  463  172.0    True  False
# 464   0.0  464  173.0   False  False
# 465   0.0  465  173.0   False  False
# 466  34.0  466  173.0   False   True
# 467   0.0  467  173.0   False  False
#
# [468 rows x 5 columns]
# 11.974613506916192
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 344.0, 'main_peak_meantime': 255.994, 'main_peak_start': 252.894, 'main_peak_end': 260.317}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 463  17.0  463  166.0   False   True
# 464   0.0  464  166.0    True  False
# 465   0.0  465  167.0   False  False
# 466   0.0  466  167.0   False  False
# 467   0.0  467  167.0   False  False
#
# [468 rows x 5 columns]
# 13.877866814037027
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1075.0, 'main_peak_meantime': 202.375, 'main_peak_start': 200.651, 'main_peak_end': 203.156}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1    12.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 463   0.0  463  177.0   False  False
# 464   0.0  464  177.0   False  False
# 465   0.0  465  178.0   False  False
# 466   0.0  466  178.0   False  False
# 467   0.0  467  178.0   False  False
#
# [468 rows x 5 columns]
# 26.088715113927464
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 228.0, 'main_peak_meantime': 228.5, 'main_peak_start': 227.719, 'main_peak_end': 229.348}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1    17.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 463  21.0  463  184.0   False  False
# 464  33.0  464  184.0   False   True
# 465  30.0  465  184.0   False  False
# 466  29.0  466  184.0   False  False
# 467   0.0  467  184.0    True  False
#
# [468 rows x 5 columns]
# 9.059602649006623
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 10032.0, 'main_peak_meantime': 311.596, 'main_peak_start': 304.657, 'main_peak_end': 317.004}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 463  13.0  463  190.0   False  False
# 464  19.0  464  191.0   False  False
# 465  20.0  465  191.0   False  False
# 466  27.0  466  191.0   False   True
# 467   0.0  467  191.0    True  False
#
# [468 rows x 5 columns]
# 407.947529514648
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 778.0, 'main_peak_meantime': 208.398, 'main_peak_start': 206.034, 'main_peak_end': 209.164}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False  False
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 463   0.0  463  192.0   False  False
# 464   0.0  464  193.0   False  False
# 465   0.0  465  193.0   False  False
# 466  20.0  466  194.0   False   True
# 467  16.0  467  194.0   False  False
#
# [468 rows x 5 columns]
# 26.832560726868163
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 346.0, 'main_peak_meantime': 220.277, 'main_peak_start': 214.606, 'main_peak_end': 221.946}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0   False   True
# 2    0.0    2    1.0    True  False
# 3    0.0    3    2.0   False   True
# 4    0.0    4    2.0    True  False
# ..   ...  ...    ...     ...    ...
# 463  0.0  463  163.0   False  False
# 464  0.0  464  163.0   False  False
# 465  0.0  465  164.0   False  False
# 466  0.0  466  164.0   False  False
# 467  0.0  467  164.0   False  False
#
# [468 rows x 5 columns]
# 10.696145568381922
# /Volumes/MICHAEL E-H 1/BIFFAMYCIN/Biffamycin Media Screen/17Sep_Reanalysis/1/EICs_Q5All_MM_1_1-1-8_1_1296.d.tsv
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1025.0, 'main_peak_meantime': 263.426, 'main_peak_start': 258.308, 'main_peak_end': 268.361}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0   False  False
# 2     8.0    2    1.0   False   True
# 3     0.0    3    1.0    True  False
# 4     0.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 358  18.0  358  135.0   False   True
# 359   0.0  359  135.0    True  False
# 360   0.0  360  136.0   False  False
# 361   0.0  361  136.0   False  False
# 362   0.0  362  136.0   False  False
#
# [363 rows x 5 columns]
# 116.83937823834196
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 190.0, 'main_peak_meantime': 268.361, 'main_peak_start': 265.66, 'main_peak_end': 270.228}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0    True  False
# 2    0.0    2    2.0   False  False
# 3    0.0    3    2.0    True  False
# 4    0.0    4    3.0   False  False
# ..   ...  ...    ...     ...    ...
# 358  0.0  358  136.0   False  False
# 359  0.0  359  136.0   False  False
# 360  0.0  360  137.0   False  False
# 361  0.0  361  137.0   False  False
# 362  0.0  362  137.0   False  False
#
# [363 rows x 5 columns]
# 13.674242424242424
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 433.0, 'main_peak_meantime': 252.787, 'main_peak_start': 248.425, 'main_peak_end': 261.054}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 358   0.0  358  131.0    True  False
# 359  22.0  359  132.0   False  False
# 360  14.0  360  132.0   False  False
# 361   6.0  361  132.0   False  False
# 362  10.0  362  132.0   False  False
#
# [363 rows x 5 columns]
# 40.752941176470586
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 84.0, 'main_peak_meantime': 258.308, 'main_peak_start': 252.787, 'main_peak_end': 261.054}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2    16.0    2    1.0   False  False
# 3     0.0    3    2.0    True  False
# 4    18.0    4    2.0   False   True
# ..    ...  ...    ...     ...    ...
# 358   0.0  358  127.0   False  False
# 359   0.0  359  127.0   False  False
# 360   0.0  360  128.0   False  False
# 361   0.0  361  128.0   False  False
# 362  41.0  362  128.0   False   True
#
# [363 rows x 5 columns]
# 5.642585551330798
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 62.0, 'main_peak_meantime': 453.89, 'main_peak_start': 450.193, 'main_peak_end': 455.898}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 358  19.0  358  134.0   False  False
# 359  21.0  359  134.0   False   True
# 360   0.0  360  134.0    True  False
# 361   0.0  361  135.0   False  False
# 362   0.0  362  135.0   False  False
#
# [363 rows x 5 columns]
# 6.291325695581015
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 106.0, 'main_peak_meantime': 281.351, 'main_peak_start': 280.305, 'main_peak_end': 285.891}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    1.0   False  False
# 3     0.0    3    2.0    True  False
# 4    15.0    4    2.0   False   True
# ..    ...  ...    ...     ...    ...
# 358   0.0  358  141.0   False  False
# 359   0.0  359  141.0   False  False
# 360   0.0  360  142.0   False  False
# 361   0.0  361  142.0   False  False
# 362   0.0  362  142.0   False  False
#
# [363 rows x 5 columns]
# 7.159894459102903
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 135.0, 'main_peak_meantime': 453.89, 'main_peak_start': 441.084, 'main_peak_end': 464.94}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0   False  False
# 2     0.0    2    2.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 358   0.0  358  136.0   False  False
# 359  11.0  359  137.0   False   True
# 360   0.0  360  137.0   False  False
# 361   0.0  361  138.0   False  False
# 362   0.0  362  138.0   False  False
#
# [363 rows x 5 columns]
# 17.5
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1321.0, 'main_peak_meantime': 247.476, 'main_peak_start': 240.145, 'main_peak_end': 252.787}
#         y    x   labx  valley   peak
# 0    11.0    0    1.0   False   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0   False   True
# 4     0.0    4    3.0    True  False
# ..    ...  ...    ...     ...    ...
# 358   0.0  358  132.0   False  False
# 359   0.0  359  133.0   False  False
# 360   0.0  360  133.0   False  False
# 361   0.0  361  134.0   False  False
# 362   0.0  362  134.0   False  False
#
# [363 rows x 5 columns]
# 108.37290242386575
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 54.0, 'main_peak_meantime': 394.955, 'main_peak_start': 391.024, 'main_peak_end': 396.483}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0   False  False
# 2     0.0    2    2.0    True  False
# 3    15.0    3    2.0   False   True
# 4     0.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 358   0.0  358  141.0   False  False
# 359  11.0  359  142.0   False  False
# 360  17.0  360  142.0   False   True
# 361   0.0  361  142.0   False  False
# 362   0.0  362  142.0   False  False
#
# [363 rows x 5 columns]
# 6.830430797433547
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 152.0, 'main_peak_meantime': 240.145, 'main_peak_start': 231.559, 'main_peak_end': 242.551}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0    True  False
# 2    0.0    2    2.0   False  False
# 3    0.0    3    2.0    True  False
# 4    0.0    4    3.0   False  False
# ..   ...  ...    ...     ...    ...
# 358  0.0  358  128.0   False  False
# 359  0.0  359  128.0   False  False
# 360  0.0  360  129.0   False  False
# 361  0.0  361  129.0   False  False
# 362  0.0  362  129.0   False  False
#
# [363 rows x 5 columns]
# 7.431734317343173
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 61.0, 'main_peak_meantime': 394.955, 'main_peak_start': 393.417, 'main_peak_end': 395.715}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 358   0.0  358  134.0   False  False
# 359   0.0  359  134.0   False  False
# 360  10.0  360  135.0   False   True
# 361   0.0  361  135.0   False  False
# 362   0.0  362  135.0   False  False
#
# [363 rows x 5 columns]
# 7.358391608391609
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 96.0, 'main_peak_meantime': 231.559, 'main_peak_start': 230.538, 'main_peak_end': 234.196}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 358  38.0  358  140.0   False  False
# 359  47.0  359  140.0   False   True
# 360  44.0  360  140.0   False  False
# 361  36.0  361  140.0   False  False
# 362  22.0  362  140.0   False  False
#
# [363 rows x 5 columns]
# 5.463761671854157
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 75.0, 'main_peak_meantime': 340.202, 'main_peak_start': 337.865, 'main_peak_end': 342.143}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False  False
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 358  23.0  358  135.0   False   True
# 359   0.0  359  135.0    True  False
# 360   0.0  360  136.0   False  False
# 361   0.0  361  136.0   False  False
# 362   0.0  362  136.0   False  False
#
# [363 rows x 5 columns]
# 7.258064516129032
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# Warning more than two max peaks - taking the first
# {'main_peak_count': 90.0, 'main_peak_meantime': 219.142, 'main_peak_start': 217.775, 'main_peak_end': 220.406}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False  False
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 358   0.0  358  136.0   False  False
# 359   0.0  359  136.0   False  False
# 360   0.0  360  137.0   False  False
# 361   0.0  361  137.0   False  False
# 362  53.0  362  137.0   False   True
#
# [363 rows x 5 columns]
# 5.437201907790143
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# Warning more than two max peaks - taking the first
# {'main_peak_count': 250.0, 'main_peak_meantime': 394.184, 'main_peak_start': 393.417, 'main_peak_end': 398.042}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 358  61.0  358  130.0   False   True
# 359  50.0  359  130.0   False  False
# 360  55.0  360  131.0   False  False
# 361   0.0  361  131.0    True  False
# 362  55.0  362  131.0   False  False
#
# [363 rows x 5 columns]
# 11.671521719736083
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 103.0, 'main_peak_meantime': 220.406, 'main_peak_start': 219.142, 'main_peak_end': 222.029}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0    True  False
# 2    0.0    2    2.0   False   True
# 3    0.0    3    2.0    True  False
# 4    0.0    4    3.0   False   True
# ..   ...  ...    ...     ...    ...
# 358  0.0  358  145.0   False  False
# 359  0.0  359  145.0   False  False
# 360  0.0  360  146.0   False  False
# 361  0.0  361  146.0   False  False
# 362  0.0  362  146.0   False  False
#
# [363 rows x 5 columns]
# 6.842476094614997
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 233.0, 'main_peak_meantime': 23.424, 'main_peak_start': 22.634, 'main_peak_end': 24.193}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 358  23.0  358  137.0   False  False
# 359  23.0  359  137.0   False  False
# 360  32.0  360  137.0   False   True
# 361   0.0  361  137.0   False  False
# 362   0.0  362  137.0   False  False
#
# [363 rows x 5 columns]
# 22.3765243902439
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 152.0, 'main_peak_meantime': 278.743, 'main_peak_start': 275.628, 'main_peak_end': 281.351}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0   False   True
# 2    0.0    2    1.0    True  False
# 3    0.0    3    2.0   False   True
# 4    0.0    4    2.0    True  False
# ..   ...  ...    ...     ...    ...
# 358  0.0  358  141.0   False  False
# 359  0.0  359  142.0   False  False
# 360  0.0  360  142.0   False  False
# 361  0.0  361  143.0   False  False
# 362  0.0  362  143.0   False  False
#
# [363 rows x 5 columns]
# 15.04950495049505
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 171.0, 'main_peak_meantime': 300.947, 'main_peak_start': 299.409, 'main_peak_end': 301.707}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0   False  False
# 2    10.0    2    1.0   False  False
# 3     0.0    3    1.0    True  False
# 4     0.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 358   0.0  358  134.0   False  False
# 359   0.0  359  135.0   False  False
# 360   0.0  360  135.0   False  False
# 361   0.0  361  135.0   False  False
# 362  25.0  362  135.0   False   True
#
# [363 rows x 5 columns]
# 6.878237081409557
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 3447.0, 'main_peak_meantime': 311.989, 'main_peak_start': 310.129, 'main_peak_end': 314.31}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 358   0.0  358  144.0   False  False
# 359  35.0  359  145.0   False   True
# 360   0.0  360  145.0   False  False
# 361  29.0  361  146.0   False  False
# 362  30.0  362  146.0   False  False
#
# [363 rows x 5 columns]
# 188.09252669039148
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 134.0, 'main_peak_meantime': 397.259, 'main_peak_start': 394.955, 'main_peak_end': 398.042}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0   False  False
# 2     0.0    2    2.0    True  False
# 3    11.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 358   0.0  358  149.0   False  False
# 359   0.0  359  150.0   False  False
# 360   0.0  360  150.0   False  False
# 361  31.0  361  151.0   False   True
# 362   0.0  362  151.0   False  False
#
# [363 rows x 5 columns]
# 8.684618895481515
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 98.0, 'main_peak_meantime': 26.488, 'main_peak_start': 25.723, 'main_peak_end': 28.034}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False   True
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 358   0.0  358  132.0   False  False
# 359  22.0  359  133.0   False   True
# 360   0.0  360  133.0   False  False
# 361   0.0  361  134.0   False  False
# 362   0.0  362  134.0   False  False
#
# [363 rows x 5 columns]
# 6.256529309344167
# /Volumes/MICHAEL E-H 1/BIFFAMYCIN/Biffamycin Media Screen/17Sep_Reanalysis/1/EICs_Q5WT_ISP2_1_1-1-24_1_1314.d.tsv
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 123.0, 'main_peak_meantime': 204.471, 'main_peak_start': 201.374, 'main_peak_end': 206.485}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 409   0.0  409  149.0   False  False
# 410  12.0  410  150.0   False   True
# 411   0.0  411  150.0   False  False
# 412   0.0  412  151.0   False  False
# 413   0.0  413  151.0   False  False
#
# [414 rows x 5 columns]
# 8.12153110047847
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 172.0, 'main_peak_meantime': 214.65, 'main_peak_start': 212.342, 'main_peak_end': 215.415}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 409   0.0  409  143.0    True  False
# 410   0.0  410  144.0   False  False
# 411   0.0  411  144.0   False  False
# 412   0.0  412  144.0   False  False
# 413  40.0  413  144.0   False   True
#
# [414 rows x 5 columns]
# 7.677059402691171
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 7943.0, 'main_peak_meantime': 213.111, 'main_peak_start': 209.807, 'main_peak_end': 218.494}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1    10.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    3.0    True  False
# ..    ...  ...    ...     ...    ...
# 409  29.0  409  142.0   False   True
# 410  14.0  410  142.0   False  False
# 411  16.0  411  143.0   False  False
# 412  21.0  412  143.0   False  False
# 413  16.0  413  143.0   False  False
#
# [414 rows x 5 columns]
# 218.00039207998432
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 185.0, 'main_peak_meantime': 236.106, 'main_peak_start': 233.805, 'main_peak_end': 236.863}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1    10.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 409   0.0  409  148.0   False  False
# 410   0.0  410  148.0   False  False
# 411  13.0  411  149.0   False  False
# 412  28.0  412  149.0   False   True
# 413   0.0  413  149.0   False  False
#
# [414 rows x 5 columns]
# 8.284491274283832
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# Warning more than two max peaks - taking the first
# {'main_peak_count': 78.0, 'main_peak_meantime': 207.513, 'main_peak_start': 203.007, 'main_peak_end': 208.281}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 409  15.0  409  146.0   False   True
# 410   0.0  410  146.0    True  False
# 411   0.0  411  147.0   False  False
# 412   0.0  412  147.0   False  False
# 413   0.0  413  147.0   False  False
#
# [414 rows x 5 columns]
# 5.231707317073171
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 138.0, 'main_peak_meantime': 225.106, 'main_peak_start': 223.156, 'main_peak_end': 229.249}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2    31.0    2    1.0   False   True
# 3     0.0    3    1.0    True  False
# 4     0.0    4    2.0   False   True
# ..    ...  ...    ...     ...    ...
# 409   0.0  409  151.0   False  False
# 410   0.0  410  152.0   False  False
# 411   0.0  411  152.0   False  False
# 412   0.0  412  152.0   False  False
# 413  15.0  413  152.0   False   True
#
# [414 rows x 5 columns]
# 5.821030430852667
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 102.0, 'main_peak_meantime': 27.213, 'main_peak_start': 24.927, 'main_peak_end': 30.259}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    1.0   False  False
# 3     0.0    3    2.0    True  False
# 4    10.0    4    2.0   False   True
# ..    ...  ...    ...     ...    ...
# 409   0.0  409  145.0    True  False
# 410   0.0  410  146.0   False  False
# 411   0.0  411  146.0   False  False
# 412   0.0  412  147.0   False  False
# 413   0.0  413  147.0   False  False
#
# [414 rows x 5 columns]
# 5.879231473010065
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 812.0, 'main_peak_meantime': 173.971, 'main_peak_start': 169.77, 'main_peak_end': 177.199}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False  False
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 409  21.0  409  147.0   False  False
# 410  24.0  410  147.0   False   True
# 411   0.0  411  147.0    True  False
# 412   0.0  412  148.0   False  False
# 413   0.0  413  148.0   False  False
#
# [414 rows x 5 columns]
# 25.03559283609159
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 166.0, 'main_peak_meantime': 234.568, 'main_peak_start': 227.654, 'main_peak_end': 235.335}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2     9.0    2    1.0   False   True
# 3     0.0    3    1.0    True  False
# 4     0.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 409  21.0  409  147.0   False   True
# 410   0.0  410  147.0   False  False
# 411   0.0  411  148.0   False  False
# 412  15.0  412  148.0   False  False
# 413   0.0  413  148.0   False  False
#
# [414 rows x 5 columns]
# 12.181818181818182
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 174.0, 'main_peak_meantime': 215.415, 'main_peak_start': 213.111, 'main_peak_end': 216.31}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 409   0.0  409  152.0   False  False
# 410   0.0  410  152.0   False  False
# 411   0.0  411  153.0   False  False
# 412   0.0  412  153.0   False  False
# 413  31.0  413  153.0   False   True
#
# [414 rows x 5 columns]
# 8.31976092641016
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 120.0, 'main_peak_meantime': 229.249, 'main_peak_start': 226.513, 'main_peak_end': 232.023}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0   False  False
# 2     0.0    2    2.0    True  False
# 3    17.0    3    2.0   False   True
# 4     0.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 409  15.0  409  150.0   False  False
# 410  10.0  410  150.0   False  False
# 411   0.0  411  150.0   False  False
# 412   0.0  412  151.0   False  False
# 413   0.0  413  151.0   False  False
#
# [414 rows x 5 columns]
# 7.758620689655173
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 171.0, 'main_peak_meantime': 418.134, 'main_peak_start': 411.335, 'main_peak_end': 419.995}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2    23.0    2    1.0   False   True
# 3     0.0    3    1.0    True  False
# 4     0.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 409   0.0  409  155.0    True  False
# 410   0.0  410  156.0   False  False
# 411   0.0  411  156.0   False  False
# 412   0.0  412  157.0   False  False
# 413   0.0  413  157.0   False  False
#
# [414 rows x 5 columns]
# 7.544945670069147
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 121.0, 'main_peak_meantime': 218.494, 'main_peak_start': 213.111, 'main_peak_end': 220.347}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 409   0.0  409  155.0   False  False
# 410   0.0  410  155.0   False  False
# 411   0.0  411  155.0   False  False
# 412   0.0  412  155.0   False  False
# 413  17.0  413  155.0   False   True
#
# [414 rows x 5 columns]
# 9.32263242375602
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 214.0, 'main_peak_meantime': 217.435, 'main_peak_start': 214.65, 'main_peak_end': 218.494}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 409   0.0  409  157.0   False  False
# 410  28.0  410  157.0   False  False
# 411  36.0  411  157.0   False  False
# 412  39.0  412  157.0   False   True
# 413   0.0  413  157.0   False  False
#
# [414 rows x 5 columns]
# 7.430555555555555
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 110.0, 'main_peak_meantime': 409.071, 'main_peak_start': 406.772, 'main_peak_end': 410.013}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False   True
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False   True
# ..    ...  ...    ...     ...    ...
# 409  36.0  409  151.0    True  False
# 410  39.0  410  152.0   False  False
# 411  38.0  411  152.0   False  False
# 412  43.0  412  153.0   False  False
# 413  39.0  413  153.0   False  False
#
# [414 rows x 5 columns]
# 6.416344942262217
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 208.0, 'main_peak_meantime': 207.513, 'main_peak_start': 206.485, 'main_peak_end': 209.807}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False   True
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False   True
# ..    ...  ...    ...     ...    ...
# 409   0.0  409  162.0   False  False
# 410  36.0  410  163.0   False   True
# 411  31.0  411  163.0   False  False
# 412   0.0  412  163.0   False  False
# 413   0.0  413  163.0   False  False
#
# [414 rows x 5 columns]
# 11.010014306151646
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 177.0, 'main_peak_meantime': 226.513, 'main_peak_start': 225.106, 'main_peak_end': 227.654}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 409   0.0  409  149.0   False  False
# 410   0.0  410  150.0   False  False
# 411   0.0  411  150.0   False  False
# 412   0.0  412  150.0   False  False
# 413  22.0  413  150.0   False   True
#
# [414 rows x 5 columns]
# 10.299910474485229
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 207.0, 'main_peak_meantime': 208.281, 'main_peak_start': 206.485, 'main_peak_end': 209.807}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 409  33.0  409  157.0   False  False
# 410  38.0  410  157.0   False   True
# 411  37.0  411  157.0   False  False
# 412   0.0  412  157.0   False  False
# 413  20.0  413  157.0   False  False
#
# [414 rows x 5 columns]
# 8.487187217365088
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 126.0, 'main_peak_meantime': 435.247, 'main_peak_start': 427.799, 'main_peak_end': 437.282}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2    21.0    2    1.0   False   True
# 3     0.0    3    1.0    True  False
# 4     0.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 409   0.0  409  160.0   False  False
# 410  15.0  410  161.0   False  False
# 411  20.0  411  161.0   False  False
# 412  25.0  412  161.0   False   True
# 413   0.0  413  161.0   False  False
#
# [414 rows x 5 columns]
# 6.510917030567685
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 2195.0, 'main_peak_meantime': 311.78, 'main_peak_start': 305.282, 'main_peak_end': 316.403}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 409   0.0  409  158.0   False  False
# 410   0.0  410  159.0   False  False
# 411   0.0  411  159.0   False  False
# 412  28.0  412  160.0   False   True
# 413   0.0  413  160.0   False  False
#
# [414 rows x 5 columns]
# 103.84064737005913
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 442.0, 'main_peak_meantime': 208.281, 'main_peak_start': 207.513, 'main_peak_end': 209.04}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 409  11.0  409  158.0   False  False
# 410  13.0  410  158.0   False  False
# 411   8.0  411  158.0   False  False
# 412   0.0  412  158.0    True  False
# 413  15.0  413  158.0   False  False
#
# [414 rows x 5 columns]
# 18.276890866265376
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 240.0, 'main_peak_meantime': 221.89, 'main_peak_start': 212.342, 'main_peak_end': 226.513}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0   False  False
# 2    0.0    2    1.0    True  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    2.0   False  False
# ..   ...  ...    ...     ...    ...
# 409  0.0  409  148.0   False  False
# 410  0.0  410  148.0   False  False
# 411  0.0  411  149.0   False  False
# 412  0.0  412  149.0   False  False
# 413  0.0  413  149.0   False  False
#
# [414 rows x 5 columns]
# 12.251428571428571
# /Volumes/MICHAEL E-H 1/BIFFAMYCIN/Biffamycin Media Screen/17Sep_Reanalysis/2/EICs_Q5All_ISP2_2_2-2-30_1_1599.d.tsv
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1136.0, 'main_peak_meantime': 262.66, 'main_peak_start': 260.33, 'main_peak_end': 269.345}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# ...
# 552  20.0  552  197.0   False   True
# 553   0.0  553  197.0   False  False
# 554   0.0  554  198.0   False  False
# 555   0.0  555  198.0   False  False
#
# [556 rows x 5 columns]
# 8.529253167969804
# /Volumes/MICHAEL E-H 1/BIFFAMYCIN/Biffamycin Media Screen/17Sep_Reanalysis/4/EICs_Q5WT_YEMETSB_4_3-2-13_1_2057.d.tsv
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 375.0, 'main_peak_meantime': 197.532, 'main_peak_start': 192.643, 'main_peak_end': 199.975}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 452   0.0  452  167.0   False  False
# 453   0.0  453  167.0   False  False
# 454  10.0  454  168.0   False   True
# 455  10.0  455  168.0   False  False
# 456  10.0  456  168.0   False  False
#
# [457 rows x 5 columns]
# 14.738805970149253
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 335.0, 'main_peak_meantime': 218.041, 'main_peak_start': 217.008, 'main_peak_end': 220.354}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False   True
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False   True
# ..    ...  ...    ...     ...    ...
# 452   0.0  452  164.0   False  False
# 453   0.0  453  164.0   False  False
# 454   0.0  454  165.0   False  False
# 455   0.0  455  165.0   False  False
# 456  32.0  456  165.0   False   True
#
# [457 rows x 5 columns]
# 8.933333333333334
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 999.0, 'main_peak_meantime': 213.118, 'main_peak_start': 212.348, 'main_peak_end': 214.709}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0   False  False
# 2     0.0    2    1.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 452  12.0  452  164.0   False  False
# 453  15.0  453  165.0   False  False
# 454   0.0  454  165.0    True  False
# 455   9.0  455  166.0   False  False
# 456  19.0  456  166.0   False   True
#
# [457 rows x 5 columns]
# 25.905996758508913
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1416.0, 'main_peak_meantime': 216.246, 'main_peak_start': 213.906, 'main_peak_end': 217.008}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0   False  False
# 2    0.0    2    1.0    True  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    2.0   False  False
# ..   ...  ...    ...     ...    ...
# 452  0.0  452  165.0   False  False
# 453  0.0  453  166.0   False  False
# 454  0.0  454  166.0   False  False
# 455  0.0  455  167.0   False  False
# 456  0.0  456  167.0   False  False
#
# [457 rows x 5 columns]
# 41.32759588400374
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 731.0, 'main_peak_meantime': 228.439, 'main_peak_start': 227.678, 'main_peak_end': 230.713}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2    12.0    2    1.0   False   True
# 3     0.0    3    1.0    True  False
# 4     0.0    4    2.0   False   True
# ..    ...  ...    ...     ...    ...
# 452   0.0  452  165.0   False  False
# 453   0.0  453  166.0   False  False
# 454   0.0  454  166.0   False  False
# 455   0.0  455  167.0   False  False
# 456   0.0  456  167.0   False  False
#
# [457 rows x 5 columns]
# 32.699234844025895
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 255.0, 'main_peak_meantime': 200.738, 'main_peak_start': 198.419, 'main_peak_end': 201.578}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2    24.0    2    1.0   False   True
# 3     0.0    3    1.0    True  False
# 4     0.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 452   0.0  452  176.0   False  False
# 453   0.0  453  176.0   False  False
# 454   0.0  454  177.0   False  False
# 455   0.0  455  177.0   False  False
# 456   0.0  456  177.0   False  False
#
# [457 rows x 5 columns]
# 8.303571428571429
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 443.0, 'main_peak_meantime': 266.015, 'main_peak_start': 259.477, 'main_peak_end': 269.98}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 452  13.0  452  160.0   False   True
# 453   6.0  453  160.0   False  False
# 454   0.0  454  160.0   False  False
# 455   0.0  455  160.0   False  False
# 456  27.0  456  160.0   False   True
#
# [457 rows x 5 columns]
# 17.154136283630876
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 586.0, 'main_peak_meantime': 174.334, 'main_peak_start': 166.832, 'main_peak_end': 180.315}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 452  19.0  452  158.0   False  False
# 453  21.0  453  158.0   False  False
# 454  19.0  454  158.0   False  False
# 455   0.0  455  158.0   False  False
# 456  16.0  456  158.0   False  False
#
# [457 rows x 5 columns]
# 14.523607843137254
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 2604.0, 'main_peak_meantime': 248.383, 'main_peak_start': 241.981, 'main_peak_end': 255.027}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0    True  False
# 2    0.0    2    2.0   False  False
# 3    0.0    3    2.0    True  False
# 4    0.0    4    3.0   False  False
# ..   ...  ...    ...     ...    ...
# 452  0.0  452  175.0   False  False
# 453  0.0  453  176.0   False  False
# 454  0.0  454  176.0   False  False
# 455  0.0  455  177.0   False  False
# 456  0.0  456  177.0   False  False
#
# [457 rows x 5 columns]
# 120.69130655000038
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 414.0, 'main_peak_meantime': 252.821, 'main_peak_start': 250.018, 'main_peak_end': 255.027}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 452  67.0  452  184.0   False   True
# 453  55.0  453  184.0   False  False
# 454  61.0  454  185.0   False  False
# 455  80.0  455  185.0   False   True
# 456  69.0  456  185.0   False  False
#
# [457 rows x 5 columns]
# 17.325196163905844
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 596.0, 'main_peak_meantime': 236.927, 'main_peak_start': 234.631, 'main_peak_end': 239.46}
#         y    x   labx  valley   peak
# 0    17.0    0    1.0   False   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False   True
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 452   0.0  452  171.0   False  False
# 453   0.0  453  171.0   False  False
# 454   0.0  454  172.0   False  False
# 455   0.0  455  172.0   False  False
# 456   0.0  456  172.0   False  False
#
# [457 rows x 5 columns]
# 24.287906853664992
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 535.0, 'main_peak_meantime': 205.832, 'main_peak_start': 204.718, 'main_peak_end': 208.208}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     8.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 452  29.0  452  174.0   False   True
# 453   0.0  453  174.0   False  False
# 454   0.0  454  175.0   False  False
# 455   0.0  455  175.0   False  False
# 456   0.0  456  175.0   False  False
#
# [457 rows x 5 columns]
# 13.988115449915112
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1332.0, 'main_peak_meantime': 204.718, 'main_peak_start': 197.532, 'main_peak_end': 210.807}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0   False  False
# 2    0.0    2    1.0    True  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    2.0   False  False
# ..   ...  ...    ...     ...    ...
# 452  0.0  452  157.0   False  False
# 453  0.0  453  158.0   False  False
# 454  0.0  454  158.0   False  False
# 455  0.0  455  159.0   False  False
# 456  0.0  456  159.0   False  False
#
# [457 rows x 5 columns]
# 36.80272263187748
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 6280.0, 'main_peak_meantime': 218.817, 'main_peak_start': 213.906, 'main_peak_end': 219.587}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0   False   True
# 2    0.0    2    1.0    True  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    2.0    True  False
# ..   ...  ...    ...     ...    ...
# 452  0.0  452  176.0   False  False
# 453  0.0  453  176.0   False  False
# 454  0.0  454  177.0   False  False
# 455  0.0  455  177.0   False  False
# 456  0.0  456  177.0   False  False
#
# [457 rows x 5 columns]
# 83.25399216631514
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 411.0, 'main_peak_meantime': 452.25, 'main_peak_start': 448.798, 'main_peak_end': 458.278}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0    True  False
# 2    0.0    2    2.0   False   True
# 3    0.0    3    2.0    True  False
# 4    0.0    4    3.0   False   True
# ..   ...  ...    ...     ...    ...
# 452  0.0  452  169.0   False  False
# 453  0.0  453  170.0   False  False
# 454  0.0  454  170.0   False  False
# 455  0.0  455  171.0   False  False
# 456  0.0  456  171.0   False  False
#
# [457 rows x 5 columns]
# 12.299682104153122
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 278.0, 'main_peak_meantime': 236.927, 'main_peak_start': 234.631, 'main_peak_end': 237.814}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 452   0.0  452  184.0   False  False
# 453   0.0  453  184.0   False  False
# 454  41.0  454  185.0   False   True
# 455   0.0  455  185.0   False  False
# 456   0.0  456  185.0   False  False
#
# [457 rows x 5 columns]
# 14.392796848621272
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 357.0, 'main_peak_meantime': 215.48, 'main_peak_start': 214.709, 'main_peak_end': 216.246}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0   False  False
# 2     0.0    2    2.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    3.0    True  False
# ..    ...  ...    ...     ...    ...
# 452   0.0  452  172.0   False  False
# 453   0.0  453  173.0   False  False
# 454   0.0  454  173.0   False  False
# 455  19.0  455  174.0   False   True
# 456  18.0  456  174.0   False  False
#
# [457 rows x 5 columns]
# 13.20365168539326
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 2322.0, 'main_peak_meantime': 240.447, 'main_peak_start': 239.46, 'main_peak_end': 242.751}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True  False
# 1    0.0    1    1.0    True  False
# 2    0.0    2    2.0   False  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    3.0   False  False
# ..   ...  ...    ...     ...    ...
# 452  0.0  452  187.0   False  False
# 453  0.0  453  188.0   False  False
# 454  0.0  454  188.0   False  False
# 455  0.0  455  189.0   False  False
# 456  0.0  456  189.0   False  False
#
# [457 rows x 5 columns]
# 88.96906805028937
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1537.0, 'main_peak_meantime': 313.676, 'main_peak_start': 312.129, 'main_peak_end': 318.704}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    1.0   False  False
# 3     0.0    3    2.0    True  False
# 4    19.0    4    2.0   False   True
# ..    ...  ...    ...     ...    ...
# 452   0.0  452  190.0   False  False
# 453   0.0  453  190.0   False  False
# 454   0.0  454  190.0   False  False
# 455  27.0  455  191.0   False   True
# 456  26.0  456  191.0   False  False
#
# [457 rows x 5 columns]
# 111.03199174406605
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 555.0, 'main_peak_meantime': 224.614, 'main_peak_start': 223.746, 'main_peak_end': 225.382}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0    True  False
# 2    0.0    2    2.0   False  False
# 3    0.0    3    2.0    True  False
# 4    0.0    4    3.0   False  False
# ..   ...  ...    ...     ...    ...
# 452  0.0  452  177.0   False  False
# 453  0.0  453  177.0   False  False
# 454  0.0  454  178.0   False  False
# 455  0.0  455  178.0   False  False
# 456  0.0  456  178.0   False  False
#
# [457 rows x 5 columns]
# 19.616759332803813
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 924.0, 'main_peak_meantime': 209.742, 'main_peak_start': 208.968, 'main_peak_end': 212.348}
#         y    x   labx  valley   peak
# 0    14.0    0    1.0   False  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    3.0    True  False
# ..    ...  ...    ...     ...    ...
# 452  13.0  452  186.0   False  False
# 453   0.0  453  186.0    True  False
# 454   0.0  454  187.0   False  False
# 455   0.0  455  187.0   False  False
# 456  27.0  456  187.0   False   True
#
# [457 rows x 5 columns]
# 33.03847648659153
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 410.0, 'main_peak_meantime': 208.208, 'main_peak_start': 202.362, 'main_peak_end': 208.968}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 452   0.0  452  157.0   False  False
# 453  27.0  453  158.0   False   True
# 454   0.0  454  158.0   False  False
# 455   0.0  455  159.0   False  False
# 456   0.0  456  159.0   False  False
#
# [457 rows x 5 columns]
# 8.749033554971392

# %%
eicarea_tsv_fromdir("/Volumes/MICHAEL E-H 1/BIFFAMYCIN/ORDER OF EVENTS/8September/1/eics/")
eicarea_tsv_fromdir("/Volumes/MICHAEL E-H 1/BIFFAMYCIN/ORDER OF EVENTS/8September/2/eics/")
# Out:
# /Volumes/MICHAEL E-H 1/BIFFAMYCIN/ORDER OF EVENTS/8September/1/eics/EICs_M1152_6HE_FIJK_1_3-2-15_1_3874.d.tsv
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1709.0, 'main_peak_meantime': 148.337, 'main_peak_start': 146.243, 'main_peak_end': 152.769}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0    True  False
# 2     34.0     2    1.0   False   True
# 3      0.0     3    1.0    True  False
# 4      0.0     4    2.0   False   True
# ...    ...   ...    ...     ...    ...
# 1130   0.0  1130  499.0    True  False
# 1131   0.0  1131  500.0   False  False
# 1132   2.0  1132  500.0   False  False
# 1133   1.0  1133  500.0   False  False
# 1134   1.0  1134  500.0   False  False
#
# [1135 rows x 5 columns]
# 173.81548490700973
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 2194.0, 'main_peak_meantime': 268.244, 'main_peak_start': 263.629, 'main_peak_end': 274.865}
#          y     x   labx  valley   peak
# 0     24.0     0    1.0   False   True
# 1      0.0     1    1.0    True  False
# 2      0.0     2    2.0    True  False
# 3     22.0     3    2.0   False  False
# 4      0.0     4    2.0    True  False
# ...    ...   ...    ...     ...    ...
# 1130   6.0  1130  413.0   False   True
# 1131   4.0  1131  413.0   False  False
# 1132   5.0  1132  414.0   False  False
# 1133   0.0  1133  414.0   False  False
# 1134   0.0  1134  414.0   False  False
#
# [1135 rows x 5 columns]
# 154.35575702629194
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 98.0, 'main_peak_meantime': 131.703, 'main_peak_start': 131.414, 'main_peak_end': 131.852}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True   True
# 1     0.0     1    1.0    True  False
# 2     0.0     2    2.0   False  False
# 3     0.0     3    2.0    True  False
# 4     0.0     4    3.0   False  False
# ...   ...   ...    ...     ...    ...
# 1130  0.0  1130  458.0   False  False
# 1131  0.0  1131  458.0   False  False
# 1132  0.0  1132  459.0   False  False
# 1133  0.0  1133  459.0   False  False
# 1134  0.0  1134  459.0   False  False
#
# [1135 rows x 5 columns]
# 10.970149253731343
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1283.0, 'main_peak_meantime': 242.359, 'main_peak_start': 236.388, 'main_peak_end': 246.919}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True  False
# 1     0.0     1    1.0   False  False
# 2     0.0     2    1.0   False  False
# 3     0.0     3    2.0    True  False
# 4     0.0     4    2.0   False  False
# ...   ...   ...    ...     ...    ...
# 1130  0.0  1130  451.0   False  False
# 1131  0.0  1131  451.0   False  False
# 1132  0.0  1132  452.0   False  False
# 1133  0.0  1133  452.0   False  False
# 1134  5.0  1134  452.0   False   True
#
# [1135 rows x 5 columns]
# 158.87871077184056
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 3322.0, 'main_peak_meantime': 215.986, 'main_peak_start': 211.757, 'main_peak_end': 221.71}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True   True
# 1     0.0     1    1.0    True  False
# 2     0.0     2    2.0   False   True
# 3     0.0     3    2.0    True  False
# 4     0.0     4    3.0   False   True
# ...   ...   ...    ...     ...    ...
# 1130  0.0  1130  444.0    True  False
# 1131  0.0  1131  445.0   False  False
# 1132  0.0  1132  445.0   False  False
# 1133  0.0  1133  445.0   False  False
# 1134  4.0  1134  445.0   False  False
#
# [1135 rows x 5 columns]
# 179.8130125751777
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 6323.0, 'main_peak_meantime': 277.967, 'main_peak_start': 273.123, 'main_peak_end': 286.114}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0   False  False
# 2     29.0     2    1.0   False   True
# 3      0.0     3    1.0    True  False
# 4      0.0     4    2.0    True  False
# ...    ...   ...    ...     ...    ...
# 1130   0.0  1130  449.0   False  False
# 1131   0.0  1131  450.0   False  False
# 1132   0.0  1132  450.0   False  False
# 1133   0.0  1133  451.0   False  False
# 1134   0.0  1134  451.0   False  False
#
# [1135 rows x 5 columns]
# 642.3803805605554
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 240255.0, 'main_peak_meantime': 243.878, 'main_peak_start': 238.694, 'main_peak_end': 258.074}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True  False
# 1     0.0     1    1.0   False  False
# 2     0.0     2    1.0   False  False
# 3     0.0     3    2.0    True  False
# 4     0.0     4    2.0   False  False
# ...   ...   ...    ...     ...    ...
# 1130  0.0  1130  464.0   False  False
# 1131  0.0  1131  465.0   False  False
# 1132  0.0  1132  465.0   False  False
# 1133  0.0  1133  466.0   False  False
# 1134  0.0  1134  466.0   False  False
#
# [1135 rows x 5 columns]
# 2904.9365642858947
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 423960.0, 'main_peak_meantime': 294.629, 'main_peak_start': 290.045, 'main_peak_end': 310.077}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0   False  False
# 2      0.0     2    2.0    True  False
# 3     16.0     3    2.0   False   True
# 4      0.0     4    2.0    True  False
# ...    ...   ...    ...     ...    ...
# 1130   4.0  1130  457.0   False   True
# 1131   0.0  1131  457.0   False  False
# 1132   0.0  1132  458.0   False  False
# 1133   0.0  1133  458.0   False  False
# 1134   0.0  1134  458.0   False  False
#
# [1135 rows x 5 columns]
# 35579.82129338845
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 177.0, 'main_peak_meantime': 111.171, 'main_peak_start': 110.757, 'main_peak_end': 112.29}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0    True  False
# 2     21.0     2    1.0   False   True
# 3      0.0     3    2.0    True  False
# 4     15.0     4    2.0   False  False
# ...    ...   ...    ...     ...    ...
# 1130   0.0  1130  454.0   False  False
# 1131   0.0  1131  454.0   False  False
# 1132   0.0  1132  455.0   False  False
# 1133   0.0  1133  455.0   False  False
# 1134   0.0  1134  455.0   False  False
#
# [1135 rows x 5 columns]
# 21.288163265306125
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 820.0, 'main_peak_meantime': 404.256, 'main_peak_start': 398.229, 'main_peak_end': 414.344}
#           y     x   labx  valley   peak
# 0     106.0     0    1.0   False  False
# 1     210.0     1    1.0   False   True
# 2       0.0     2    1.0    True  False
# 3       0.0     3    2.0    True  False
# 4     165.0     4    2.0   False  False
# ...     ...   ...    ...     ...    ...
# 1130    0.0  1130  374.0    True  False
# 1131    0.0  1131  375.0   False  False
# 1132    0.0  1132  375.0   False  False
# 1133    0.0  1133  376.0   False  False
# 1134    0.0  1134  376.0   False  False
#
# [1135 rows x 5 columns]
# 11.354727959412404
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 122.0, 'main_peak_meantime': 79.515, 'main_peak_start': 79.356, 'main_peak_end': 79.959}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0   False  False
# 2     15.0     2    1.0   False   True
# 3      0.0     3    1.0    True  False
# 4      0.0     4    2.0    True  False
# ...    ...   ...    ...     ...    ...
# 1130   0.0  1130  456.0   False  False
# 1131   0.0  1131  456.0   False  False
# 1132  11.0  1132  457.0   False   True
# 1133   0.0  1133  457.0   False  False
# 1134   0.0  1134  457.0   False  False
#
# [1135 rows x 5 columns]
# 11.529730951842641
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 510.0, 'main_peak_meantime': 243.115, 'main_peak_start': 238.694, 'main_peak_end': 248.46}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0   False  False
# 2      0.0     2    1.0   False  False
# 3      0.0     3    2.0    True  False
# 4      0.0     4    2.0   False  False
# ...    ...   ...    ...     ...    ...
# 1130  26.0  1130  465.0   False  False
# 1131  31.0  1131  465.0   False   True
# 1132  20.0  1132  465.0   False  False
# 1133  23.0  1133  466.0   False  False
# 1134  22.0  1134  466.0   False  False
#
# [1135 rows x 5 columns]
# 61.41228939544103
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 220.0, 'main_peak_meantime': 282.686, 'main_peak_start': 277.967, 'main_peak_end': 285.168}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0    True  False
# 2     18.0     2    1.0   False   True
# 3      0.0     3    1.0   False  False
# 4      0.0     4    2.0    True  False
# ...    ...   ...    ...     ...    ...
# 1130   0.0  1130  470.0   False  False
# 1131   0.0  1131  471.0   False  False
# 1132   0.0  1132  471.0   False  False
# 1133   0.0  1133  472.0   False  False
# 1134   0.0  1134  472.0   False  False
#
# [1135 rows x 5 columns]
# 37.141856392294216
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 4598.0, 'main_peak_meantime': 281.915, 'main_peak_start': 277.197, 'main_peak_end': 290.045}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0   False  False
# 2      0.0     2    1.0    True  False
# 3      0.0     3    2.0   False  False
# 4     27.0     4    2.0   False   True
# ...    ...   ...    ...     ...    ...
# 1130   0.0  1130  444.0   False  False
# 1131   0.0  1131  444.0   False  False
# 1132   0.0  1132  445.0   False  False
# 1133   0.0  1133  445.0   False  False
# 1134   0.0  1134  445.0   False  False
#
# [1135 rows x 5 columns]
# 325.1957543827371
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 117.0, 'main_peak_meantime': 138.135, 'main_peak_start': 137.986, 'main_peak_end': 138.274}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True   True
# 1     0.0     1    1.0    True  False
# 2     0.0     2    2.0   False   True
# 3     0.0     3    2.0    True  False
# 4     0.0     4    3.0   False  False
# ...   ...   ...    ...     ...    ...
# 1130  0.0  1130  500.0   False  False
# 1131  0.0  1131  500.0   False  False
# 1132  6.0  1132  501.0   False   True
# 1133  0.0  1133  501.0   False  False
# 1134  0.0  1134  501.0   False  False
#
# [1135 rows x 5 columns]
# 42.80323139065205
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 167.0, 'main_peak_meantime': 274.865, 'main_peak_start': 273.939, 'main_peak_end': 277.197}
#          y     x   labx  valley   peak
# 0      9.0     0    1.0   False  False
# 1      0.0     1    1.0    True  False
# 2      0.0     2    2.0   False  False
# 3      0.0     3    2.0    True  False
# 4      0.0     4    2.0   False  False
# ...    ...   ...    ...     ...    ...
# 1130  14.0  1130  425.0   False  False
# 1131   9.0  1131  425.0   False  False
# 1132  11.0  1132  426.0   False  False
# 1133   0.0  1133  426.0    True  False
# 1134   0.0  1134  426.0   False  False
#
# [1135 rows x 5 columns]
# 11.612582781456954
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 137.0, 'main_peak_meantime': 248.46, 'main_peak_start': 243.878, 'main_peak_end': 250.207}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True   True
# 1      0.0     1    1.0   False   True
# 2      0.0     2    1.0    True  False
# 3      0.0     3    2.0   False   True
# 4      0.0     4    2.0    True  False
# ...    ...   ...    ...     ...    ...
# 1130   0.0  1130  506.0   False  False
# 1131  26.0  1131  506.0   False  False
# 1132   0.0  1132  506.0   False  False
# 1133   0.0  1133  507.0   False  False
# 1134   0.0  1134  507.0   False  False
#
# [1135 rows x 5 columns]
# 61.25857142857142
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 605.0, 'main_peak_meantime': 298.413, 'main_peak_start': 293.105, 'main_peak_end': 299.93}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True   True
# 1      0.0     1    1.0   False   True
# 2      0.0     2    1.0    True  False
# 3      0.0     3    2.0   False   True
# 4      0.0     4    2.0    True  False
# ...    ...   ...    ...     ...    ...
# 1130  13.0  1130  507.0   False   True
# 1131   0.0  1131  507.0   False  False
# 1132   0.0  1132  508.0   False  False
# 1133  10.0  1133  508.0   False  False
# 1134   6.0  1134  508.0   False  False
#
# [1135 rows x 5 columns]
# 315.6091578086672
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 35.0, 'main_peak_meantime': 36.483, 'main_peak_start': 33.806, 'main_peak_end': 38.766}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True   True
# 1     0.0     1    1.0   False   True
# 2     0.0     2    1.0    True  False
# 3     0.0     3    2.0   False   True
# 4     0.0     4    2.0    True  False
# ...   ...   ...    ...     ...    ...
# 1130  0.0  1130  529.0   False  False
# 1131  6.0  1131  529.0   False  False
# 1132  4.0  1132  529.0   False  False
# 1133  0.0  1133  529.0   False  False
# 1134  0.0  1134  529.0   False  False
#
# [1135 rows x 5 columns]
# 39.16786226685796
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 41.0, 'main_peak_meantime': 451.499, 'main_peak_start': 441.876, 'main_peak_end': 455.517}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True   True
# 1     0.0     1    1.0    True  False
# 2     0.0     2    2.0   False   True
# 3     0.0     3    2.0    True  False
# 4     0.0     4    3.0   False   True
# ...   ...   ...    ...     ...    ...
# 1130  0.0  1130  527.0   False  False
# 1131  0.0  1131  527.0   False  False
# 1132  0.0  1132  528.0   False  False
# 1133  0.0  1133  528.0   False  False
# 1134  0.0  1134  528.0   False  False
#
# [1135 rows x 5 columns]
# 41.26867627785059
# /Volumes/MICHAEL E-H 1/BIFFAMYCIN/ORDER OF EVENTS/8September/1/eics/EICs_M1152_EF_1_2-2-41_1_3847.d.tsv
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1799.0, 'main_peak_meantime': 155.204, 'main_peak_start': 155.048, 'main_peak_end': 157.156}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    1.0   False  False
# 3     0.0    3    2.0    True  False
# 4    13.0    4    2.0   False   True
# ..    ...  ...    ...     ...    ...
# 549   6.0  549  228.0   False  False
# 550   0.0  550  228.0    True  False
# 551   0.0  551  229.0   False  False
# 552   0.0  552  229.0   False  False
# 553   0.0  553  229.0   False  False
#
# [554 rows x 5 columns]
# 117.68202502844142
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1226.0, 'main_peak_meantime': 279.769, 'main_peak_start': 273.678, 'main_peak_end': 286.306}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0   False  False
# 2    0.0    2    1.0    True  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    2.0   False  False
# ..   ...  ...    ...     ...    ...
# 549  6.0  549  210.0   False  False
# 550  8.0  550  210.0   False   True
# 551  0.0  551  210.0   False  False
# 552  0.0  552  211.0   False  False
# 553  0.0  553  211.0   False  False
#
# [554 rows x 5 columns]
# 96.56849315068493
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1619.0, 'main_peak_meantime': 248.238, 'main_peak_start': 236.592, 'main_peak_end': 250.515}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True  False
# 1    0.0    1    1.0   False  False
# 2    0.0    2    2.0    True  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    3.0    True  False
# ..   ...  ...    ...     ...    ...
# 549  0.0  549  226.0   False  False
# 550  0.0  550  226.0   False  False
# 551  0.0  551  227.0   False  False
# 552  0.0  552  227.0   False  False
# 553  0.0  553  227.0   False  False
#
# [554 rows x 5 columns]
# 203.16862745098038
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 32904.0, 'main_peak_meantime': 247.476, 'main_peak_start': 236.592, 'main_peak_end': 260.047}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1    15.0    1    1.0   False  False
# 2    15.0    2    1.0   False  False
# 3     0.0    3    1.0    True  False
# 4     0.0    4    1.0   False  False
# ..    ...  ...    ...     ...    ...
# 549   0.0  549  219.0   False  False
# 550   0.0  550  220.0   False  False
# 551   0.0  551  220.0   False  False
# 552   0.0  552  221.0   False  False
# 553   0.0  553  221.0   False  False
#
# [554 rows x 5 columns]
# 3869.0447450572324
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 87833.0, 'main_peak_meantime': 219.253, 'main_peak_start': 213.592, 'main_peak_end': 232.271}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0    True  False
# 2    0.0    2    2.0   False   True
# 3    0.0    3    2.0    True  False
# 4    0.0    4    3.0   False   True
# ..   ...  ...    ...     ...    ...
# 549  4.0  549  211.0   False  False
# 550  0.0  550  211.0    True  False
# 551  0.0  551  212.0   False  False
# 552  0.0  552  212.0   False  False
# 553  0.0  553  212.0   False  False
#
# [554 rows x 5 columns]
# 2845.2365675128485
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 33635.0, 'main_peak_meantime': 290.991, 'main_peak_start': 282.315, 'main_peak_end': 303.402}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1    33.0    1    1.0   False  False
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 549   0.0  549  216.0   False  False
# 550   7.0  550  217.0   False   True
# 551   4.0  551  217.0   False  False
# 552   2.0  552  217.0   False  False
# 553   0.0  553  217.0   False  False
#
# [554 rows x 5 columns]
# 3086.901408450704
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 129.0, 'main_peak_meantime': 240.132, 'main_peak_start': 237.677, 'main_peak_end': 244.275}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True  False
# 1    0.0    1    1.0   False  False
# 2    0.0    2    2.0    True  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    3.0    True  False
# ..   ...  ...    ...     ...    ...
# 549  0.0  549  235.0   False  False
# 550  0.0  550  236.0   False  False
# 551  0.0  551  236.0   False  False
# 552  0.0  552  237.0   False  False
# 553  0.0  553  237.0   False  False
#
# [554 rows x 5 columns]
# 28.30798845043311
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 62.0, 'main_peak_meantime': 249.004, 'main_peak_start': 245.507, 'main_peak_end': 249.771}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 549   0.0  549  222.0    True  False
# 550  13.0  550  223.0   False   True
# 551   0.0  551  223.0   False  False
# 552   0.0  552  224.0   False  False
# 553   0.0  553  224.0   False  False
#
# [554 rows x 5 columns]
# 9.340507302075327
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 72.0, 'main_peak_meantime': 170.584, 'main_peak_start': 170.432, 'main_peak_end': 170.738}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True  False
# 1    0.0    1    1.0    True  False
# 2    0.0    2    2.0   False  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    3.0    True  False
# ..   ...  ...    ...     ...    ...
# 549  0.0  549  229.0   False  False
# 550  7.0  550  230.0   False   True
# 551  4.0  551  230.0   False  False
# 552  0.0  552  230.0   False  False
# 553  7.0  553  230.0   False  False
#
# [554 rows x 5 columns]
# 10.512396694214877
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 706.0, 'main_peak_meantime': 248.238, 'main_peak_start': 242.84, 'main_peak_end': 253.863}
#          y    x   labx  valley   peak
# 0     11.0    0    1.0   False  False
# 1    121.0    1    1.0   False  False
# 2      0.0    2    2.0    True  False
# 3    125.0    3    2.0   False   True
# 4    106.0    4    2.0   False  False
# ..     ...  ...    ...     ...    ...
# 549    0.0  549  191.0   False  False
# 550    0.0  550  191.0   False  False
# 551    0.0  551  192.0   False  False
# 552    0.0  552  192.0   False  False
# 553    0.0  553  192.0   False  False
#
# [554 rows x 5 columns]
# 10.193988837876123
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 87.0, 'main_peak_meantime': 207.373, 'main_peak_start': 202.679, 'main_peak_end': 208.186}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 549   0.0  549  238.0    True  False
# 550   0.0  550  239.0   False  False
# 551   0.0  551  239.0   False  False
# 552  13.0  552  239.0   False   True
# 553   0.0  553  239.0   False  False
#
# [554 rows x 5 columns]
# 16.6079295154185
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 355.0, 'main_peak_meantime': 219.253, 'main_peak_start': 218.397, 'main_peak_end': 220.018}
#         y    x   labx  valley   peak
# 0     8.0    0    1.0   False  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0    True  False
# 3    16.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 549   0.0  549  230.0   False  False
# 550  21.0  550  231.0   False   True
# 551  20.0  551  231.0   False  False
# 552  17.0  552  231.0   False  False
# 553  17.0  553  231.0   False  False
#
# [554 rows x 5 columns]
# 49.288582903040734
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 48.0, 'main_peak_meantime': 112.023, 'main_peak_start': 111.875, 'main_peak_end': 113.468}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2    11.0    2    1.0   False   True
# 3     0.0    3    1.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 549   0.0  549  229.0   False  False
# 550   0.0  550  230.0   False  False
# 551   0.0  551  230.0   False  False
# 552   0.0  552  231.0   False  False
# 553   0.0  553  231.0   False  False
#
# [554 rows x 5 columns]
# 9.574354407836154
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 117.0, 'main_peak_meantime': 116.254, 'main_peak_start': 114.808, 'main_peak_end': 118.043}
#         y    x   labx  valley   peak
# 0    14.0    0    1.0   False  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0    True  False
# 3    15.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 549  14.0  549  221.0   False   True
# 550  12.0  550  221.0   False  False
# 551   8.0  551  221.0   False  False
# 552   5.0  552  221.0    True  False
# 553   6.0  553  221.0   False  False
#
# [554 rows x 5 columns]
# 14.510977107452845
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 68.0, 'main_peak_meantime': 275.963, 'main_peak_start': 275.213, 'main_peak_end': 276.728}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0   False  False
# 2     0.0    2    2.0   False  False
# 3    21.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 549   0.0  549  244.0   False  False
# 550   0.0  550  244.0   False  False
# 551   0.0  551  245.0   False  False
# 552   0.0  552  245.0   False  False
# 553   0.0  553  245.0   False  False
#
# [554 rows x 5 columns]
# 23.34328358208955
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 94.0, 'main_peak_meantime': 169.538, 'main_peak_start': 169.388, 'main_peak_end': 170.143}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True  False
# 1    0.0    1    1.0   False  False
# 2    0.0    2    2.0   False  False
# 3    0.0    3    2.0    True  False
# 4    0.0    4    3.0   False  False
# ..   ...  ...    ...     ...    ...
# 549  0.0  549  212.0   False  False
# 550  0.0  550  212.0   False  False
# 551  0.0  551  213.0   False  False
# 552  0.0  552  213.0   False  False
# 553  0.0  553  213.0   False  False
#
# [554 rows x 5 columns]
# 6.56156862745098
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 41.0, 'main_peak_meantime': 290.991, 'main_peak_start': 287.234, 'main_peak_end': 291.752}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 549   0.0  549  249.0   False  False
# 550   0.0  550  250.0   False  False
# 551   0.0  551  250.0   False  False
# 552  18.0  552  251.0   False   True
# 553  17.0  553  251.0   False  False
#
# [554 rows x 5 columns]
# 25.996086105675147
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 54.0, 'main_peak_meantime': 453.699, 'main_peak_start': 443.506, 'main_peak_end': 457.719}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1    16.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 549  11.0  549  241.0   False   True
# 550   6.0  550  241.0   False  False
# 551   0.0  551  241.0   False  False
# 552   0.0  552  242.0   False  False
# 553   0.0  553  242.0   False  False
#
# [554 rows x 5 columns]
# 27.586956521739133
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 40.0, 'main_peak_meantime': 453.699, 'main_peak_start': 450.079, 'main_peak_end': 460.734}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0   False   True
# 2    0.0    2    1.0    True  False
# 3    0.0    3    2.0   False   True
# 4    0.0    4    2.0    True  False
# ..   ...  ...    ...     ...    ...
# 549  0.0  549  253.0   False  False
# 550  0.0  550  254.0   False  False
# 551  0.0  551  254.0   False  False
# 552  0.0  552  255.0   False  False
# 553  0.0  553  255.0   False  False
#
# [554 rows x 5 columns]
# 27.447698744769877
# /Volumes/MICHAEL E-H 1/BIFFAMYCIN/ORDER OF EVENTS/8September/1/eics/EICs_M1152_EFIJK_1_2-2-42_1_3848.d.tsv
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1133.0, 'main_peak_meantime': 148.799, 'main_peak_start': 146.586, 'main_peak_end': 149.806}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0   False   True
# 2    0.0    2    1.0    True  False
# 3    0.0    3    2.0   False   True
# 4    0.0    4    2.0    True  False
# ..   ...  ...    ...     ...    ...
# 793  0.0  793  336.0    True  False
# 794  6.0  794  337.0   False  False
# 795  4.0  795  337.0   False  False
# 796  2.0  796  337.0   False  False
# 797  0.0  797  337.0   False  False
#
# [798 rows x 5 columns]
# 68.15793006689455
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1652.0, 'main_peak_meantime': 268.096, 'main_peak_start': 266.49, 'main_peak_end': 274.477}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0   False  False
# 2     0.0    2    2.0   False  False
# 3    19.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 793   0.0  793  316.0   False  False
# 794   0.0  794  317.0   False  False
# 795   0.0  795  317.0   False  False
# 796   0.0  796  318.0   False  False
# 797   0.0  797  318.0   False  False
#
# [798 rows x 5 columns]
# 177.6765519968367
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 97.0, 'main_peak_meantime': 243.008, 'main_peak_start': 235.45, 'main_peak_end': 245.539}
#        y    x   labx  valley   peak
# 0    9.0    0    1.0   False   True
# 1    0.0    1    1.0    True  False
# 2    0.0    2    2.0   False  False
# 3    0.0    3    2.0    True  False
# 4    0.0    4    3.0   False  False
# ..   ...  ...    ...     ...    ...
# 793  0.0  793  324.0   False  False
# 794  0.0  794  324.0   False  False
# 795  0.0  795  325.0   False  False
# 796  0.0  796  325.0   False  False
# 797  0.0  797  325.0   False  False
#
# [798 rows x 5 columns]
# 14.513940520446097
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1150.0, 'main_peak_meantime': 242.249, 'main_peak_start': 235.45, 'main_peak_end': 247.057}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2    11.0    2    1.0   False   True
# 3     0.0    3    1.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 793   0.0  793  310.0   False  False
# 794   0.0  794  310.0   False  False
# 795   7.0  795  311.0   False   True
# 796   4.0  796  311.0   False  False
# 797   0.0  797  311.0   False  False
#
# [798 rows x 5 columns]
# 122.56795422031475
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1577.0, 'main_peak_meantime': 203.818, 'main_peak_start': 201.682, 'main_peak_end': 212.779}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2    20.0    2    1.0   False   True
# 3     0.0    3    1.0    True  False
# 4     0.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 793   0.0  793  306.0   False  False
# 794   0.0  794  306.0   False  False
# 795   4.0  795  307.0   False  False
# 796   5.0  796  307.0   False   True
# 797   3.0  797  307.0   False  False
#
# [798 rows x 5 columns]
# 106.72045809474231
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 735.0, 'main_peak_meantime': 226.903, 'main_peak_start': 223.849, 'main_peak_end': 233.004}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2    19.0    2    1.0   False   True
# 3     0.0    3    1.0    True  False
# 4     0.0    4    2.0   False  False
# ..    ...  ...    ...     ...    ...
# 793   0.0  793  311.0   False  False
# 794   0.0  794  312.0   False  False
# 795   0.0  795  312.0   False  False
# 796   0.0  796  313.0   False  False
# 797   0.0  797  313.0   False  False
#
# [798 rows x 5 columns]
# 51.74152876280536
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 6596.0, 'main_peak_meantime': 243.761, 'main_peak_start': 238.044, 'main_peak_end': 250.854}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0   False  False
# 2    0.0    2    1.0    True  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    2.0    True  False
# ..   ...  ...    ...     ...    ...
# 793  6.0  793  322.0   False  False
# 794  4.0  794  322.0   False  False
# 795  2.0  795  322.0   False  False
# 796  0.0  796  322.0    True  False
# 797  0.0  797  322.0   False  False
#
# [798 rows x 5 columns]
# 237.30860797530806
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 79479.0, 'main_peak_meantime': 294.85, 'main_peak_start': 289.447, 'main_peak_end': 306.59}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    1.0   False  False
# 3     0.0    3    2.0   False  False
# 4    11.0    4    2.0   False   True
# ..    ...  ...    ...     ...    ...
# 793  10.0  793  316.0   False  False
# 794  20.0  794  317.0   False   True
# 795  17.0  795  317.0   False  False
# 796  11.0  796  317.0   False  False
# 797   7.0  797  317.0    True  False
#
# [798 rows x 5 columns]
# 11363.426702488026
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# Warning more than two max peaks - taking the first
# {'main_peak_count': 57.0, 'main_peak_meantime': 59.339, 'main_peak_start': 59.193, 'main_peak_end': 62.433}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3     0.0    3    2.0    True  False
# 4     0.0    4    3.0   False  False
# ..    ...  ...    ...     ...    ...
# 793  11.0  793  331.0   False   True
# 794   7.0  794  331.0   False  False
# 795   0.0  795  331.0    True  False
# 796   0.0  796  332.0   False  False
# 797  10.0  797  332.0   False  False
#
# [798 rows x 5 columns]
# 8.90625
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1267.0, 'main_peak_meantime': 418.637, 'main_peak_start': 414.719, 'main_peak_end': 420.456}
#          y    x   labx  valley   peak
# 0     92.0    0    1.0    True  False
# 1    163.0    1    1.0   False   True
# 2    120.0    2    2.0   False  False
# 3    144.0    3    2.0   False  False
# 4    113.0    4    2.0   False  False
# ..     ...  ...    ...     ...    ...
# 793    0.0  793  254.0   False  False
# 794    0.0  794  255.0   False  False
# 795    0.0  795  255.0   False  False
# 796    8.0  796  256.0   False   True
# 797    5.0  797  256.0   False  False
#
# [798 rows x 5 columns]
# 14.708101644939228
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 110.0, 'main_peak_meantime': 320.671, 'main_peak_start': 318.206, 'main_peak_end': 322.389}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True  False
# 1    0.0    1    1.0   False  False
# 2    0.0    2    2.0    True  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    3.0    True  False
# ..   ...  ...    ...     ...    ...
# 793  0.0  793  328.0   False  False
# 794  0.0  794  328.0   False  False
# 795  0.0  795  329.0   False  False
# 796  0.0  796  329.0   False  False
# 797  0.0  797  329.0   False  False
#
# [798 rows x 5 columns]
# 11.945701357466062
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 128.0, 'main_peak_meantime': 250.854, 'main_peak_start': 247.804, 'main_peak_end': 251.833}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0   False  False
# 2     0.0    2    2.0   False  False
# 3    18.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 793   0.0  793  345.0   False  False
# 794   0.0  794  345.0   False  False
# 795   0.0  795  345.0   False  False
# 796   0.0  796  345.0   False  False
# 797  13.0  797  345.0   False  False
#
# [798 rows x 5 columns]
# 26.28751974723539
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 240.0, 'main_peak_meantime': 293.313, 'main_peak_start': 288.568, 'main_peak_end': 296.396}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0   False  False
# 2    0.0    2    1.0    True  False
# 3    0.0    3    2.0   False  False
# 4    0.0    4    2.0   False  False
# ..   ...  ...    ...     ...    ...
# 793  0.0  793  341.0   False  False
# 794  0.0  794  341.0   False  False
# 795  0.0  795  342.0   False  False
# 796  0.0  796  342.0   False  False
# 797  0.0  797  342.0   False  False
#
# [798 rows x 5 columns]
# 55.10763209393346
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1265.0, 'main_peak_meantime': 293.313, 'main_peak_start': 288.568, 'main_peak_end': 297.926}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    1.0   False  False
# 3     0.0    3    2.0    True  False
# 4    21.0    4    2.0   False   True
# ..    ...  ...    ...     ...    ...
# 793   4.0  793  331.0   False  False
# 794   0.0  794  331.0    True  False
# 795   0.0  795  332.0   False  False
# 796   0.0  796  332.0   False  False
# 797   0.0  797  332.0   False  False
#
# [798 rows x 5 columns]
# 165.5045871559633
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 70.0, 'main_peak_meantime': 213.649, 'main_peak_start': 212.779, 'main_peak_end': 214.417}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2    23.0    2    1.0   False   True
# 3     0.0    3    1.0    True  False
# 4     0.0    4    2.0   False   True
# ..    ...  ...    ...     ...    ...
# 793   0.0  793  342.0   False  False
# 794   0.0  794  342.0   False  False
# 795   0.0  795  342.0   False  False
# 796   0.0  796  342.0   False  False
# 797   6.0  797  342.0   False  False
#
# [798 rows x 5 columns]
# 18.243626062322946
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 85.0, 'main_peak_meantime': 65.143, 'main_peak_start': 64.718, 'main_peak_end': 65.277}
#         y    x   labx  valley   peak
# 0    20.0    0    1.0   False  False
# 1     0.0    1    1.0    True  False
# 2     0.0    2    2.0   False  False
# 3    18.0    3    2.0   False  False
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 793   0.0  793  299.0   False  False
# 794   0.0  794  299.0   False  False
# 795   0.0  795  300.0   False  False
# 796   0.0  796  300.0   False  False
# 797   0.0  797  300.0   False  False
#
# [798 rows x 5 columns]
# 5.672187043351194
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 94.0, 'main_peak_meantime': 248.572, 'main_peak_start': 246.298, 'main_peak_end': 251.833}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0    True  False
# 2    0.0    2    2.0   False   True
# 3    0.0    3    2.0    True  False
# 4    0.0    4    3.0   False   True
# ..   ...  ...    ...     ...    ...
# 793  0.0  793  345.0   False  False
# 794  0.0  794  346.0   False  False
# 795  0.0  795  346.0   False  False
# 796  0.0  796  347.0   False  False
# 797  0.0  797  347.0   False  False
#
# [798 rows x 5 columns]
# 28.128486897717664
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 77.0, 'main_peak_meantime': 297.926, 'main_peak_start': 295.622, 'main_peak_end': 298.882}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 793   8.0  793  360.0   False  False
# 794   0.0  794  360.0   False  False
# 795  14.0  795  361.0   False   True
# 796   9.0  796  361.0   False  False
# 797   9.0  797  361.0   False  False
#
# [798 rows x 5 columns]
# 48.728971962616825
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 38.0, 'main_peak_meantime': 29.8, 'main_peak_start': 26.105, 'main_peak_end': 30.559}
#         y    x   labx  valley   peak
# 0     0.0    0    1.0    True   True
# 1     0.0    1    1.0   False   True
# 2     0.0    2    1.0    True  False
# 3     0.0    3    2.0   False   True
# 4     0.0    4    2.0    True  False
# ..    ...  ...    ...     ...    ...
# 793   4.0  793  362.0   False  False
# 794   0.0  794  362.0   False  False
# 795   0.0  795  362.0   False  False
# 796   7.0  796  363.0   False  False
# 797  10.0  797  363.0   False   True
#
# [798 rows x 5 columns]
# 32.794520547945204
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 33.0, 'main_peak_meantime': 87.895, 'main_peak_start': 87.742, 'main_peak_end': 88.047}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0    True  False
# 2    0.0    2    2.0   False   True
# 3    0.0    3    2.0    True  False
# 4    0.0    4    3.0   False   True
# ..   ...  ...    ...     ...    ...
# 793  0.0  793  362.0   False  False
# 794  0.0  794  363.0   False  False
# 795  0.0  795  363.0   False  False
# 796  0.0  796  364.0   False  False
# 797  0.0  797  364.0   False  False
#
# [798 rows x 5 columns]
# 26.272873194221507
# /Volumes/MICHAEL E-H 1/BIFFAMYCIN/ORDER OF EVENTS/8September/1/eics/EICs_M1152_EFIK_1_3-2-13_1_3872.d.tsv
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 2554.0, 'main_peak_meantime': 148.322, 'main_peak_start': 144.78, 'main_peak_end': 156.351}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0    True  False
# 2     31.0     2    1.0   False   True
# 3      0.0     3    1.0   False  False
# 4      0.0     4    2.0    True  False
# ...    ...   ...    ...     ...    ...
# 1135   0.0  1135  496.0   False  False
# 1136   0.0  1136  497.0   False  False
# 1137   0.0  1137  497.0   False  False
# 1138   0.0  1138  498.0   False  False
# 1139   0.0  1139  498.0   False  False
#
# [1140 rows x 5 columns]
# 329.2664881338738
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 3938.0, 'main_peak_meantime': 268.415, 'main_peak_start': 265.371, 'main_peak_end': 276.056}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0   False  False
# 2     18.0     2    1.0   False  False
# 3      0.0     3    1.0    True  False
# 4      0.0     4    2.0   False  False
# ...    ...   ...    ...     ...    ...
# 1135   0.0  1135  405.0   False  False
# 1136   0.0  1136  406.0   False  False
# 1137   0.0  1137  406.0   False  False
# 1138   0.0  1138  407.0   False  False
# 1139   0.0  1139  407.0   False  False
#
# [1140 rows x 5 columns]
# 275.4947031780932
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 261.0, 'main_peak_meantime': 64.86, 'main_peak_start': 64.717, 'main_peak_end': 66.188}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0   False  False
# 2     21.0     2    1.0   False   True
# 3      0.0     3    1.0    True  False
# 4      0.0     4    2.0   False  False
# ...    ...   ...    ...     ...    ...
# 1135   0.0  1135  437.0   False  False
# 1136   0.0  1136  437.0   False  False
# 1137   0.0  1137  438.0   False  False
# 1138   0.0  1138  438.0   False  False
# 1139   6.0  1139  438.0   False   True
#
# [1140 rows x 5 columns]
# 19.703418635106868
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 105.0, 'main_peak_meantime': 31.359, 'main_peak_start': 29.04, 'main_peak_end': 32.351}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True   True
# 1     0.0     1    1.0   False  False
# 2     0.0     2    1.0    True  False
# 3     0.0     3    2.0   False  False
# 4     0.0     4    2.0   False  False
# ...   ...   ...    ...     ...    ...
# 1135  0.0  1135  463.0   False  False
# 1136  0.0  1136  463.0   False  False
# 1137  7.0  1137  464.0   False   True
# 1138  0.0  1138  464.0   False  False
# 1139  0.0  1139  464.0   False  False
#
# [1140 rows x 5 columns]
# 12.23684210526316
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 2212.0, 'main_peak_meantime': 203.812, 'main_peak_start': 197.852, 'main_peak_end': 209.575}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True  False
# 1     0.0     1    1.0   False  False
# 2     0.0     2    2.0    True  False
# 3     0.0     3    2.0   False  False
# 4     0.0     4    3.0   False  False
# ...   ...   ...    ...     ...    ...
# 1135  0.0  1135  430.0   False  False
# 1136  0.0  1136  431.0   False  False
# 1137  0.0  1137  431.0   False  False
# 1138  0.0  1138  432.0   False  False
# 1139  0.0  1139  432.0   False  False
#
# [1140 rows x 5 columns]
# 148.85598923283985
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 107.0, 'main_peak_meantime': 232.197, 'main_peak_start': 220.658, 'main_peak_end': 234.991}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True   True
# 1     0.0     1    1.0    True  False
# 2     0.0     2    2.0   False   True
# 3     0.0     3    2.0    True  False
# 4     0.0     4    3.0   False   True
# ...   ...   ...    ...     ...    ...
# 1135  0.0  1135  447.0   False  False
# 1136  0.0  1136  448.0   False  False
# 1137  0.0  1137  448.0   False  False
# 1138  0.0  1138  449.0   False  False
# 1139  0.0  1139  449.0   False  False
#
# [1140 rows x 5 columns]
# 11.443850267379679
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 619.0, 'main_peak_meantime': 243.736, 'main_peak_start': 239.146, 'main_peak_end': 248.42}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0    True  False
# 2      0.0     2    1.0   False  False
# 3      0.0     3    2.0    True  False
# 4     19.0     4    2.0   False   True
# ...    ...   ...    ...     ...    ...
# ...
# 0     0.0    0    1.0    True  False
# 1     0.0    1    1.0    True  False
# 2    13.0    2    1.0   False   True
# 3     0.0    3    1.0    True  False
# 4     0.0    4    2.0   False   True
# ..    ...  ...    ...     ...    ...
# 876   0.0  876  393.0   False  False
# 877   5.0  877  394.0   False  False
# 878  15.0  878  394.0   False   True
# 879  13.0  879  394.0   False  False
# 880   7.0  880  394.0   False  False
#
# [881 rows x 5 columns]
# 18.38064516129032
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 27.0, 'main_peak_meantime': 125.78, 'main_peak_start': 124.772, 'main_peak_end': 126.827}
#        y    x   labx  valley   peak
# 0    0.0    0    1.0    True   True
# 1    0.0    1    1.0   False   True
# 2    0.0    2    1.0    True  False
# 3    0.0    3    2.0   False   True
# 4    0.0    4    2.0    True  False
# ..   ...  ...    ...     ...    ...
# 876  0.0  876  397.0   False  False
# 877  0.0  877  398.0   False  False
# 878  0.0  878  398.0   False  False
# 879  0.0  879  399.0   False  False
# 880  0.0  880  399.0   False  False
#
# [881 rows x 5 columns]
# 15.217598097502973
# /Volumes/MICHAEL E-H 1/BIFFAMYCIN/ORDER OF EVENTS/8September/2/eics/EICs_M1152_pSET_2_2-2-51_1_3867.d.tsv
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1596.0, 'main_peak_meantime': 151.668, 'main_peak_start': 151.523, 'main_peak_end': 152.368}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True   True
# 1     0.0     1    1.0    True  False
# 2     0.0     2    2.0   False   True
# 3     0.0     3    2.0    True  False
# 4     0.0     4    3.0   False   True
# ...   ...   ...    ...     ...    ...
# 1070  0.0  1070  467.0   False  False
# 1071  0.0  1071  467.0   False  False
# 1072  3.0  1072  468.0   False   True
# 1073  0.0  1073  468.0   False  False
# 1074  0.0  1074  468.0   False  False
#
# [1075 rows x 5 columns]
# 129.2964674513537
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 7185.0, 'main_peak_meantime': 268.481, 'main_peak_start': 263.648, 'main_peak_end': 279.702}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0   False  False
# 2     17.0     2    1.0   False  False
# 3      0.0     3    1.0   False  False
# 4      0.0     4    2.0    True  False
# ...    ...   ...    ...     ...    ...
# 1070   0.0  1070  403.0   False  False
# 1071   0.0  1071  403.0   False  False
# 1072   0.0  1072  404.0   False  False
# 1073   0.0  1073  404.0   False  False
# 1074   0.0  1074  404.0   False  False
#
# [1075 rows x 5 columns]
# 532.5122615803815
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 100.0, 'main_peak_meantime': 108.254, 'main_peak_start': 108.109, 'main_peak_end': 108.537}
#          y     x   labx  valley   peak
# 0     23.0     0    1.0   False   True
# 1      0.0     1    1.0    True  False
# 2      0.0     2    2.0   False   True
# 3      0.0     3    2.0    True  False
# 4      0.0     4    3.0   False  False
# ...    ...   ...    ...     ...    ...
# 1070   0.0  1070  424.0   False  False
# 1071   0.0  1071  424.0   False  False
# 1072   0.0  1072  425.0   False  False
# 1073   0.0  1073  425.0   False  False
# 1074   0.0  1074  425.0   False  False
#
# [1075 rows x 5 columns]
# 8.965350133268718
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 124.0, 'main_peak_meantime': 242.175, 'main_peak_start': 241.407, 'main_peak_end': 244.481}
#          y     x   labx  valley   peak
# 0     14.0     0    1.0   False  False
# 1      0.0     1    1.0    True  False
# 2      0.0     2    2.0    True  False
# 3     20.0     3    2.0   False   True
# 4      0.0     4    2.0    True  False
# ...    ...   ...    ...     ...    ...
# 1070   0.0  1070  420.0   False  False
# 1071   0.0  1071  420.0   False  False
# 1072   5.0  1072  421.0   False   True
# 1073   0.0  1073  421.0   False  False
# 1074   0.0  1074  421.0   False  False
#
# [1075 rows x 5 columns]
# 10.58010665430095
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 1388.0, 'main_peak_meantime': 204.007, 'main_peak_start': 201.549, 'main_peak_end': 211.251}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0   False  False
# 2      0.0     2    2.0    True  False
# 3     10.0     3    2.0   False  False
# 4      0.0     4    3.0    True  False
# ...    ...   ...    ...     ...    ...
# 1070   0.0  1070  409.0    True  False
# 1071   0.0  1071  410.0   False  False
# 1072   0.0  1072  410.0   False  False
# 1073   7.0  1073  410.0   False   True
# 1074   0.0  1074  410.0   False  False
#
# [1075 rows x 5 columns]
# 92.33081876669732
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 149.0, 'main_peak_meantime': 227.468, 'main_peak_start': 224.901, 'main_peak_end': 228.973}
#          y     x   labx  valley   peak
# 0     36.0     0    1.0   False   True
# 1      0.0     1    1.0    True  False
# 2      0.0     2    2.0   False  False
# 3      0.0     3    2.0    True  False
# 4     34.0     4    2.0   False   True
# ...    ...   ...    ...     ...    ...
# 1070   0.0  1070  414.0   False  False
# 1071   0.0  1071  414.0   False  False
# 1072   0.0  1072  415.0   False  False
# 1073   0.0  1073  415.0   False  False
# 1074   0.0  1074  415.0   False  False
#
# [1075 rows x 5 columns]
# 11.800723866297636
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 89.0, 'main_peak_meantime': 187.804, 'main_peak_start': 187.668, 'main_peak_end': 187.962}
#          y     x   labx  valley   peak
# 0     26.0     0    1.0   False   True
# 1      0.0     1    2.0    True  False
# 2     26.0     2    2.0   False   True
# 3      0.0     3    2.0   False  False
# 4      0.0     4    3.0    True  False
# ...    ...   ...    ...     ...    ...
# 1070   0.0  1070  456.0   False  False
# 1071   0.0  1071  456.0   False  False
# 1072   0.0  1072  457.0   False  False
# 1073   0.0  1073  457.0   False  False
# 1074   0.0  1074  457.0   False  False
#
# [1075 rows x 5 columns]
# 17.23526988051092
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 96.0, 'main_peak_meantime': 295.416, 'main_peak_start': 293.566, 'main_peak_end': 296.956}
#          y     x   labx  valley   peak
# 0     29.0     0    1.0   False   True
# 1      0.0     1    1.0    True  False
# 2      0.0     2    2.0    True  False
# 3      0.0     3    2.0   False  False
# 4      0.0     4    3.0   False  False
# ...    ...   ...    ...     ...    ...
# 1070   0.0  1070  434.0   False  False
# 1071   0.0  1071  434.0   False  False
# 1072   4.0  1072  435.0   False  False
# 1073   0.0  1073  435.0   False  False
# 1074  13.0  1074  435.0   False   True
#
# [1075 rows x 5 columns]
# 14.551256481850817
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 125.0, 'main_peak_meantime': 111.315, 'main_peak_start': 110.581, 'main_peak_end': 111.891}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True  False
# 1     0.0     1    1.0   False  False
# 2     0.0     2    1.0   False  False
# 3     0.0     3    2.0    True  False
# 4     0.0     4    2.0   False  False
# ...   ...   ...    ...     ...    ...
# 1070  0.0  1070  421.0   False  False
# 1071  0.0  1071  421.0   False  False
# 1072  0.0  1072  422.0   False  False
# 1073  0.0  1073  422.0   False  False
# 1074  0.0  1074  422.0   False  False
#
# [1075 rows x 5 columns]
# 11.380145278450364
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 882.0, 'main_peak_meantime': 402.722, 'main_peak_start': 396.895, 'main_peak_end': 411.129}
#           y     x   labx  valley   peak
# 0     407.0     0    1.0   False   True
# 1       0.0     1    2.0    True  False
# 2     153.0     2    2.0   False  False
# 3     187.0     3    2.0   False  False
# 4     195.0     4    2.0   False  False
# ...     ...   ...    ...     ...    ...
# 1070    0.0  1070  349.0   False  False
# 1071    0.0  1071  349.0   False  False
# 1072    0.0  1072  350.0   False  False
# 1073    0.0  1073  350.0   False  False
# 1074    0.0  1074  350.0   False  False
#
# [1075 rows x 5 columns]
# 11.721364711196705
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 153.0, 'main_peak_meantime': 78.61, 'main_peak_start': 78.156, 'main_peak_end': 78.759}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True   True
# 1     0.0     1    1.0   False  False
# 2     0.0     2    1.0    True  False
# 3     0.0     3    2.0   False  False
# 4     0.0     4    2.0    True  False
# ...   ...   ...    ...     ...    ...
# 1070  0.0  1070  430.0   False  False
# 1071  0.0  1071  431.0   False  False
# 1072  0.0  1072  431.0   False  False
# 1073  0.0  1073  432.0   False  False
# 1074  0.0  1074  432.0   False  False
#
# [1075 rows x 5 columns]
# 14.808781869688385
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 895.0, 'main_peak_meantime': 250.972, 'main_peak_start': 246.305, 'main_peak_end': 255.406}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True   True
# 1     0.0     1    1.0    True  False
# 2     0.0     2    2.0   False  False
# 3     0.0     3    2.0    True  False
# 4     0.0     4    3.0   False  False
# ...   ...   ...    ...     ...    ...
# 1070  0.0  1070  442.0   False  False
# 1071  0.0  1071  443.0   False  False
# 1072  0.0  1072  443.0   False  False
# 1073  0.0  1073  444.0   False  False
# 1074  0.0  1074  444.0   False  False
#
# [1075 rows x 5 columns]
# 124.22375112174693
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 80.0, 'main_peak_meantime': 293.566, 'main_peak_start': 285.518, 'main_peak_end': 296.192}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True   True
# 1     0.0     1    1.0   False   True
# 2     0.0     2    1.0    True  False
# 3     0.0     3    2.0   False   True
# 4     0.0     4    2.0    True  False
# ...   ...   ...    ...     ...    ...
# 1070  2.0  1070  464.0   False  False
# 1071  1.0  1071  464.0   False  False
# 1072  0.0  1072  464.0    True  False
# 1073  0.0  1073  465.0   False  False
# 1074  0.0  1074  465.0   False  False
#
# [1075 rows x 5 columns]
# 20.1654501216545
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 488.0, 'main_peak_meantime': 292.791, 'main_peak_start': 288.181, 'main_peak_end': 296.192}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True   True
# 1     0.0     1    1.0   False  False
# 2     0.0     2    1.0    True  False
# 3     0.0     3    2.0   False  False
# 4     0.0     4    2.0   False  False
# ...   ...   ...    ...     ...    ...
# 1070  0.0  1070  434.0   False  False
# 1071  0.0  1071  434.0   False  False
# 1072  0.0  1072  435.0   False  False
# 1073  0.0  1073  435.0   False  False
# 1074  0.0  1074  435.0   False  False
#
# [1075 rows x 5 columns]
# 51.70214892553723
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 72.0, 'main_peak_meantime': 427.865, 'main_peak_start': 424.433, 'main_peak_end': 432.197}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1     28.0     1    1.0   False   True
# 2      0.0     2    1.0    True  False
# 3      9.0     3    2.0   False  False
# 4     16.0     4    2.0   False  False
# ...    ...   ...    ...     ...    ...
# 1070   3.0  1070  473.0   False  False
# 1071  11.0  1071  473.0   False   True
# 1072   0.0  1072  473.0   False  False
# 1073   0.0  1073  474.0   False  False
# 1074   0.0  1074  474.0   False  False
#
# [1075 rows x 5 columns]
# 23.40495867768595
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 80.0, 'main_peak_meantime': 124.365, 'main_peak_start': 124.219, 'main_peak_end': 124.808}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0   False  False
# 2      0.0     2    2.0    True  False
# 3     58.0     3    2.0   False  False
# 4      0.0     4    3.0   False  False
# ...    ...   ...    ...     ...    ...
# 1070   0.0  1070  405.0   False  False
# 1071   0.0  1071  405.0   False  False
# 1072   0.0  1072  406.0   False  False
# 1073   0.0  1073  406.0   False  False
# 1074   0.0  1074  406.0   False  False
#
# [1075 rows x 5 columns]
# 5.379178605539637
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 65.0, 'main_peak_meantime': 31.761, 'main_peak_start': 30.33, 'main_peak_end': 35.741}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True  False
# 1      0.0     1    1.0   False  False
# 2      0.0     2    2.0    True  False
# 3     14.0     3    2.0   False   True
# 4      0.0     4    3.0    True  False
# ...    ...   ...    ...     ...    ...
# 1070   0.0  1070  482.0   False  False
# 1071   0.0  1071  482.0   False  False
# 1072   0.0  1072  483.0   False  False
# 1073   0.0  1073  483.0   False  False
# 1074   0.0  1074  483.0   False  False
#
# [1075 rows x 5 columns]
# 31.511999999999997
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 34.0, 'main_peak_meantime': 426.258, 'main_peak_start': 424.433, 'main_peak_end': 429.814}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True   True
# 1      0.0     1    1.0    True  False
# 2      0.0     2    2.0   False   True
# 3      0.0     3    2.0    True  False
# 4      0.0     4    3.0   False   True
# ...    ...   ...    ...     ...    ...
# 1070   0.0  1070  483.0   False  False
# 1071   0.0  1071  484.0   False  False
# 1072   0.0  1072  484.0   False  False
# 1073  13.0  1073  485.0   False   True
# 1074  12.0  1074  485.0   False  False
#
# [1075 rows x 5 columns]
# 20.386036960985628
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 38.0, 'main_peak_meantime': 2.764, 'main_peak_start': 2.631, 'main_peak_end': 2.895}
#          y     x   labx  valley   peak
# 0      0.0     0    1.0    True   True
# 1      0.0     1    1.0   False  False
# 2      0.0     2    1.0    True  False
# 3      0.0     3    2.0   False  False
# 4      0.0     4    2.0    True  False
# ...    ...   ...    ...     ...    ...
# 1070   0.0  1070  480.0   False  False
# 1071  24.0  1071  481.0   False   True
# 1072  16.0  1072  481.0   False  False
# 1073  10.0  1073  481.0   False  False
# 1074   0.0  1074  481.0   False  False
#
# [1075 rows x 5 columns]
# 19.745422842197037
# [findpeaks] >Finding peaks in 1d-vector using [peakdetect] method..
# [findpeaks] >Interpolating 1d-vector by factor 5
# {'main_peak_count': 35.0, 'main_peak_meantime': 67.244, 'main_peak_start': 67.098, 'main_peak_end': 67.402}
#         y     x   labx  valley   peak
# 0     0.0     0    1.0    True   True
# 1     0.0     1    1.0    True  False
# 2     0.0     2    2.0   False  False
# 3     0.0     3    2.0    True  False
# 4     0.0     4    3.0   False  False
# ...   ...   ...    ...     ...    ...
# 1070  0.0  1070  488.0   False  False
# 1071  0.0  1071  489.0   False  False
# 1072  0.0  1072  489.0   False  False
# 1073  0.0  1073  490.0   False  False
# 1074  0.0  1074  490.0   False  False
#
# [1075 rows x 5 columns]
# 24.558659217877093
